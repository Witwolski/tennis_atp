# %%
import pandas as pd
from sqlalchemy import create_engine
import pandas as pd
import numpy as np
import datetime
devengine = create_engine("sqlite:///C:/Git/tennis_atp/database/bets_sqllite.db")
time_now = datetime.datetime.now()
time_now_formatted = time_now.strftime("%Y-%m-%d")
clay_today=pd.read_pickle('.\Clay_Today')
clay_today=clay_today[clay_today['Resulted']=='False']
clay_today[['Time','Fav_Top100','Dog_Top100','Fav','fav_rank','fav_rank_high','dog_rank','dog_rank_high','Fav_Odds','fav_percent','Fav_Serve%','Fav_Return%','fav_last_five_win_perc','Dog','Dog_Odds','dog_percent','Dog_Serve%','Dog_Return%','dog_last_five_win_perc']]
# Out:
#      Time  Fav_Top100  Dog_Top100                      Fav  fav_rank  \
# 0   05:10         0.8         0.6            Nicolas Jarry      21.0
# 1   05:10         0.5         0.1       Francisco Comesana     119.0
# 2   05:10         0.3         0.2    Felipe Meligeni Alves     151.0
# 3   05:10         0.6         0.3           Mariano Navone     117.0
# 4   23:00         0.5         0.1           Cameron Norrie      20.0
# 5   23:00         0.3         0.0       Tomas Barrios Vera     120.0
# 6   23:00         0.7         0.3         Alejandro Tabilo      54.0
# 7   23:00         0.4         0.4  Roberto Carballes Baena      64.0
# 8   23:00         0.5         0.4              Laslo Djere      35.0
# 9   23:00         0.5         0.2            Dusan Lajovic      58.0
# 10  23:00         0.3         0.4      Juan Pablo Varillas      85.0
# 11  23:00         0.5         0.5              Jaume Munar      71.0
#
# ...
