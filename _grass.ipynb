# %%
import pandas as pd
from sqlalchemy import create_engine
import pandas as pd
import numpy as np
import datetime
Fav_Win_Percentage=pd.read_pickle('Fav_Win_Percentage_Dog_Grass')
devengine = create_engine("sqlite:///C:/Git/tennis_atp/database/bets_sqllite.db")
time_now = datetime.datetime.now()
time_now_formatted = time_now.strftime("%Y-%m-%d")
Grass_today=pd.read_pickle('.\Grass_Today')
Grass_today['fav_percent_adj'] = np.ceil(Grass_today['fav_percent'] * 10) / 10
Grass_today['dog_percent_adj'] = np.ceil(Grass_today['dog_percent'] * 10) / 10
Grass_today_win_percent=pd.merge(Grass_today,Fav_Win_Percentage,left_on=['fav_percent_adj','dog_percent_adj'],right_on=['fav_percent_adj','dog_percent_adj'])
Grass_today=Grass_today[Grass_today['Sex']=='Womens']
#Grass_today=Grass_today[Grass_today['fav_percent']>Grass_today['dog_percent']]
#Grass_today=Grass_today[Grass_today['fav_percent']<Grass_today['dog_percent']]

Grass_today[['Time','Fav_Top100','Dog_Top100','Fav','fav_rank','fav_rank_high','dog_rank','dog_rank_high','Fav_Odds','fav_percent','Fav_Serve%','Fav_Return%','fav_last_five_win_perc','Dog','Dog_Odds','dog_percent','Dog_Serve%','Dog_Return%','dog_last_five_win_perc']]
#pd.read_sql('Select * FROM results_grass_1',con=devengine)
# Out:
#     Time  Fav_Top100  Dog_Top100              Fav  fav_rank  fav_rank_high  \
# 2  22:30         0.6         0.7  Jasmine Paolini       7.0            7.0
#
#    dog_rank  dog_rank_high  Fav_Odds  fav_percent  Fav_Serve%  Fav_Return%  \
# 2      37.0           19.0      1.55     0.571429        0.66         0.37
#
#    fav_last_five_win_perc          Dog  Dog_Odds  dog_percent  Dog_Serve%  \
# 2                     0.8  Donna Vekic      2.46          0.6         0.7
#
#    Dog_Return%  dog_last_five_win_perc
# 2         0.33                     0.8

# %%
import pandas as pd
from sqlalchemy import create_engine
import pandas as pd
import numpy as np
import datetime
devengine = create_engine("sqlite:///C:/Git/tennis_atp/database/bets_sqllite.db")
time_now = datetime.datetime.now()
time_now_formatted = time_now.strftime("%Y-%m-%d")
Grass_today=pd.read_pickle('.\Grass_Today')
Grass_today=Grass_today[Grass_today['Resulted']=='False']
Grass_today=Grass_today[Grass_today['Sex']!='Womens']
Grass_today['fav_percent_adj'] = np.ceil(Grass_today['fav_percent'] * 10) / 10
Grass_today['dog_percent_adj'] = np.ceil(Grass_today['dog_percent'] * 10) / 10
Grass_today[['Time','Fav_Top100','Dog_Top100','Fav','fav_rank','fav_rank_high','dog_rank','dog_rank_high','Fav_Odds','fav_percent','Fav_Serve%','Fav_Return%','fav_last_five_win_perc','Dog','Dog_Odds','dog_percent','Dog_Serve%','Dog_Return%','dog_last_five_win_perc']]
# Out:
# Empty DataFrame
# Columns: [Time, Fav_Top100, Dog_Top100, Fav, fav_rank, fav_rank_high, dog_rank, dog_rank_high, Fav_Odds, fav_percent, Fav_Serve%, Fav_Return%, fav_last_five_win_perc, Dog, Dog_Odds, dog_percent, Dog_Serve%, Dog_Return%, dog_last_five_win_perc]
# Index: []

# %%
Grass_today_win_percent=Grass_today_win_percent[Grass_today_win_percent['Resulted']=='False']
Grass_today_win_percent=Grass_today_win_percent[Grass_today_win_percent['Sex']!='Woxmens']
Grass_today_win_percent[['Time','Fav_Win_Percentage','Fav','Fav_Odds','fav_percent','dog_percent','Dog','Dog_Odds']][Grass_today_win_percent['Fav_Win_Percentage']>0.7].sort_values(by=['Fav_Win_Percentage'],ascending=False )
# Out:
#     Time  Fav_Win_Percentage              Fav  Fav_Odds  fav_percent  \
# 1  22:30                 1.0  Jasmine Paolini      1.55     0.571429
#
#    dog_percent          Dog  Dog_Odds
# 1          0.6  Donna Vekic      2.46

# %%
import pandas as pd
from sqlalchemy import create_engine
import pandas as pd
import numpy as np
import datetime
Fav_Win_Percentage=pd.read_pickle('Fav_Win_Percentage_Grass')
devengine = create_engine("sqlite:///C:/Git/tennis_atp/database/bets_sqllite.db")
time_now = datetime.datetime.now()
time_now_formatted = time_now.strftime("%Y-%m-%d")
Grass_today=pd.read_pickle('.\Grass_Today')
Grass_today['fav_percent_adj'] = np.ceil(Grass_today['fav_percent'] * 10) / 10
Grass_today['dog_percent_adj'] = np.ceil(Grass_today['dog_percent'] * 10) / 10
Grass_today_win_percent=pd.merge(Grass_today,Fav_Win_Percentage,left_on=['fav_percent_adj','dog_percent_adj'],right_on=['fav_percent_adj','dog_percent_adj'])
Grass_today=Grass_today[Grass_today['Resulted']=='False']
Grass_today=Grass_today[Grass_today['Sex']=='Womens']
#Grass_today=Grass_today[Grass_today['fav_percent']>Grass_today['dog_percent']]
#Grass_today=Grass_today[Grass_today['fav_percent']<Grass_today['dog_percent']]

Grass_today[['Time','Fav_Top100','Dog_Top100','Fav','fav_rank','fav_rank_high','dog_rank','dog_rank_high','Fav_Odds','fav_percent','Fav_Serve%','Fav_Return%','fav_last_five_win_perc','Dog','Dog_Odds','dog_percent','Dog_Serve%','Dog_Return%','dog_last_five_win_perc']]
Grass_today_win_percent=Grass_today_win_percent[Grass_today_win_percent['Resulted']=='False']
Grass_today_win_percent=Grass_today_win_percent[Grass_today_win_percent['Sex']!='Woxmcens']
Grass_today_win_percent[['Time','Fav_Win_Percentage','Fav','Fav_Odds','fav_percent','dog_percent','Dog','Dog_Odds']].sort_values(by=['Fav_Win_Percentage'],ascending=False )
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Input In [4], in <cell line: 6>()
#       4 import numpy as np
#       5 import datetime
# ----> 6 Fav_Win_Percentage=pd.read_pickle('Fav_Win_Percentage_Grass')
#       7 devengine = create_engine("sqlite:///C:/Git/tennis_atp/database/bets_sqllite.db")
#       8 time_now = datetime.datetime.now()
#
# File c:\Users\Administrator\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\io\pickle.py:187, in read_pickle(filepath_or_buffer, compression, storage_options)
#     124 """
#     125 Load pickled pandas object (or any object) from file.
#     126
#    (...)
#     184 4    4    9
#     185 """  # noqa: E501
#     186 excs_to_catch = (AttributeError, ImportError, ModuleNotFoundError, TypeError)
# --> 187 with get_handle(
#     188     filepath_or_buffer,
#     189     "rb",
#     190     compression=compression,
# ...

# %%
import pandas as pd
from sqlalchemy import create_engine
import pandas as pd
import numpy as np
import datetime
Fav_Win_Percentage=pd.read_pickle('Fav_Win_Percentage_Grass')
devengine = create_engine("sqlite:///C:/Git/tennis_atp/database/bets_sqllite.db")
time_now = datetime.datetime.now()
time_now_formatted = time_now.strftime("%Y-%m-%d")
hard_today=pd.read_pickle('.\Grass_Today')
hard_today['fav_percent_adj'] = np.ceil(hard_today['fav_percent'] * 10) / 10
hard_today['dog_percent_adj'] = np.ceil(hard_today['dog_percent'] * 10) / 10
hard_today_win_percent=pd.merge(hard_today,Fav_Win_Percentage,left_on=['fav_percent_adj','dog_percent_adj'],right_on=['fav_percent_adj','dog_percent_adj'])
hard_today_win_percent=hard_today_win_percent[hard_today_win_percent['Resulted']!='Falxse']
hard_today_win_percent=hard_today_win_percent[hard_today_win_percent['Sex']!='Woxmcens']
hard_today_win_percent[['Time','Fav_Win_Percentage','Fav','Fav_Odds','fav_percent','dog_percent','Dog','Dog_Odds']].sort_values(by=['Time'],ascending=True )#.to_clipboard(index=False)
# Out:
#      Time  Fav_Win_Percentage                     Fav  Fav_Odds  fav_percent  \
# 0   04:10            0.615385      Alexia Todoni Anca      1.66     0.600000
# 3   18:00            0.000000         Carlos Taberner      1.62     0.333333
# 4   18:00            0.692308       Raphael Collignon      1.40     0.500000
# 5   18:00            0.333333  Javier Barranco Cosano      1.64     0.625000
# 7   18:00            0.000000          Giovanni Fonio      1.47     0.500000
# 1   19:30            0.615385    Alessandro Giannessi      1.75     0.588235
# 8   19:30            0.500000  Samuel Vincent Ruggeri      1.46     0.666667
# 9   19:30            0.333333    Carlos Sanchez Jover      1.53     0.230769
# 10  21:00            1.000000            Ugo Blanchet      1.85     0.666667
# 11  21:30            0.333333       Marco Trungelliti      1.48     0.583333
# 2   23:00            0.615385    Francesco Maestrelli      1.69     0.600000
# ...
