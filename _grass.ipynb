# %%
import pandas as pd
from sqlalchemy import create_engine
import pandas as pd
import numpy as np
import datetime
Fav_Win_Percentage=pd.read_pickle('Fav_Win_Percentage_Clay')
devengine = create_engine("sqlite:///C:/Git/tennis_atp/database/bets_sqllite.db")
time_now = datetime.datetime.now()
time_now_formatted = time_now.strftime("%Y-%m-%d")
clay_today=pd.read_pickle('.\clay_Today')
clay_today['fav_percent_adj'] = np.ceil(clay_today['fav_percent'] * 10) / 10
clay_today['dog_percent_adj'] = np.ceil(clay_today['dog_percent'] * 10) / 10
clay_today_win_percent=pd.merge(clay_today,Fav_Win_Percentage,left_on=['fav_percent_adj','dog_percent_adj'],right_on=['fav_percent_adj','dog_percent_adj'])
clay_today=clay_today[clay_today['Resulted']=='False']
clay_today=clay_today[clay_today['Sex']=='Womens']
#clay_today=clay_today[clay_today['fav_percent']>clay_today['dog_percent']]
#clay_today=clay_today[clay_today['fav_percent']<clay_today['dog_percent']]

clay_today[['Time','Fav_Top100','Dog_Top100','Fav','fav_rank','fav_rank_high','dog_rank','dog_rank_high','Fav_Odds','fav_percent','Fav_Serve%','Fav_Return%','fav_last_five_win_perc','Dog','Dog_Odds','dog_percent','Dog_Serve%','Dog_Return%','dog_last_five_win_perc']]
#pd.read_sql('Select * FROM results_grass_1',con=devengine)
# Out:
#      Time  Fav_Top100  Dog_Top100                Fav  fav_rank  fav_rank_high  \
# 14  19:00         0.0         0.0  Varvara Lepchenko     234.0           19.0
#
#     dog_rank  dog_rank_high  Fav_Odds  fav_percent  Fav_Serve%  Fav_Return%  \
# 14     213.0          168.0      1.46          1.0         NaN          NaN
#
#     fav_last_five_win_perc             Dog  Dog_Odds  dog_percent  Dog_Serve%  \
# 14                0.333333  Elvina Kalieva      2.52         0.75        0.53
#
#     Dog_Return%  dog_last_five_win_perc
# 14          0.4                     0.2

# %%
import pandas as pd
from sqlalchemy import create_engine
import pandas as pd
import numpy as np
import datetime
devengine = create_engine("sqlite:///C:/Git/tennis_atp/database/bets_sqllite.db")
time_now = datetime.datetime.now()
time_now_formatted = time_now.strftime("%Y-%m-%d")
clay_today=pd.read_pickle('.\clay_Today')
clay_today=clay_today[clay_today['Resulted']=='False']
clay_today=clay_today[clay_today['Sex']!='Womens']
clay_today['fav_percent_adj'] = np.ceil(clay_today['fav_percent'] * 10) / 10
clay_today['dog_percent_adj'] = np.ceil(clay_today['dog_percent'] * 10) / 10
clay_today[['Time','Fav_Top100','Dog_Top100','Fav','fav_rank','fav_rank_high','dog_rank','dog_rank_high','Fav_Odds','fav_percent','Fav_Serve%','Fav_Return%','fav_last_five_win_perc','Dog','Dog_Odds','dog_percent','Dog_Serve%','Dog_Return%','dog_last_five_win_perc']]
# Out:
#      Time  Fav_Top100  Dog_Top100                     Fav  fav_rank  \
# 9   18:00         0.0         0.0         Carlos Taberner     309.0
# 10  18:00         0.0         0.0       Raphael Collignon     458.0
# 11  18:00         0.0         0.0  Javier Barranco Cosano     250.0
# 12  18:00         0.0         0.2          Gianluca Mager     294.0
# 13  18:00         0.0         0.0          Giovanni Fonio     297.0
# 15  19:30         0.0         0.0  Agustin Gomez Federico     312.0
# 16  19:30         0.0         0.0  Samuel Vincent Ruggeri     281.0
# 17  19:30         0.0         0.0         Guido Andreozzi     301.0
# 18  19:30         0.0         0.0    Carlos Sanchez Jover     346.0
# 19  19:30         0.2         0.0    Alessandro Giannessi     367.0
# 20  20:00         1.0         0.0              Jerome Kym     444.0
# 21  20:30         0.0         0.0             Matej Dodig     359.0
# 22  21:00         0.0         0.0         Gauthier Onclin     261.0
# ...

# %%
clay_today_win_percent=clay_today_win_percent[clay_today_win_percent['Resulted']=='False']
clay_today_win_percent=clay_today_win_percent[clay_today_win_percent['Sex']!='Woxmens']
clay_today_win_percent[['Time','Fav_Win_Percentage','Fav','Fav_Odds','fav_percent','dog_percent','Dog','Dog_Odds']][clay_today_win_percent['Fav_Win_Percentage']>0.7].sort_values(by=['Fav_Win_Percentage'],ascending=False )
# Out:
#      Time  Fav_Win_Percentage           Fav  Fav_Odds  fav_percent  \
# 10  21:00                 1.0  Ugo Blanchet      1.85     0.666667
#
#     dog_percent             Dog  Dog_Odds
# 10     0.166667  Manuel Guinard      1.88

# %%
import pandas as pd
from sqlalchemy import create_engine
import pandas as pd
import numpy as np
import datetime
Fav_Win_Percentage=pd.read_pickle('Fav_Win_Percentage_Clay')
devengine = create_engine("sqlite:///C:/Git/tennis_atp/database/bets_sqllite.db")
time_now = datetime.datetime.now()
time_now_formatted = time_now.strftime("%Y-%m-%d")
clay_today=pd.read_pickle('.\clay_Today')
clay_today['fav_percent_adj'] = np.ceil(clay_today['fav_percent'] * 10) / 10
clay_today['dog_percent_adj'] = np.ceil(clay_today['dog_percent'] * 10) / 10
clay_today_win_percent=pd.merge(clay_today,Fav_Win_Percentage,left_on=['fav_percent_adj','dog_percent_adj'],right_on=['fav_percent_adj','dog_percent_adj'])
clay_today=clay_today[clay_today['Resulted']=='False']
clay_today=clay_today[clay_today['Sex']=='Womens']
#clay_today=clay_today[clay_today['fav_percent']>clay_today['dog_percent']]
#clay_today=clay_today[clay_today['fav_percent']<clay_today['dog_percent']]

clay_today[['Time','Fav_Top100','Dog_Top100','Fav','fav_rank','fav_rank_high','dog_rank','dog_rank_high','Fav_Odds','fav_percent','Fav_Serve%','Fav_Return%','fav_last_five_win_perc','Dog','Dog_Odds','dog_percent','Dog_Serve%','Dog_Return%','dog_last_five_win_perc']]
clay_today_win_percent=clay_today_win_percent[clay_today_win_percent['Resulted']!='kFalse']
clay_today_win_percent=clay_today_win_percent[clay_today_win_percent['Sex']!='Woxmcens']
clay_today_win_percent[['Time','Fav_Win_Percentage','Fav','Fav_Odds','fav_percent','dog_percent','Dog','Dog_Odds']][clay_today_win_percent['Fav_Odds']>1.7].sort_values(by=['Time'],ascending=True )
# Out:
#      Time  Fav_Win_Percentage                   Fav  Fav_Odds  fav_percent  \
# 1   19:30            0.615385  Alessandro Giannessi      1.75     0.588235
# 10  21:00            1.000000          Ugo Blanchet      1.85     0.666667
# 6   23:30            0.333333        Norbert Gombos      1.83     0.666667
#
#     dog_percent                 Dog  Dog_Odds
# 1      0.411765      Alexander Weis      1.98
# 10     0.166667      Manuel Guinard      1.88
# 6      0.500000  Gerard Campana Lee      1.88

# %%
import pandas as pd
from sqlalchemy import create_engine
import pandas as pd
import numpy as np
import datetime
Fav_Win_Percentage=pd.read_pickle('Fav_Win_Percentage_Clay')
devengine = create_engine("sqlite:///C:/Git/tennis_atp/database/bets_sqllite.db")
time_now = datetime.datetime.now()
time_now_formatted = time_now.strftime("%Y-%m-%d")
clay_today=pd.read_pickle('.\clay_Today')
clay_today['fav_percent_adj'] = np.ceil(clay_today['fav_percent'] * 10) / 10
clay_today['dog_percent_adj'] = np.ceil(clay_today['dog_percent'] * 10) / 10
clay_today_win_percent=pd.merge(clay_today,Fav_Win_Percentage,left_on=['fav_percent_adj','dog_percent_adj'],right_on=['fav_percent_adj','dog_percent_adj'])
clay_today=clay_today[clay_today['Resulted']=='False']
clay_today=clay_today[clay_today['Sex']=='Womens']
#clay_today=clay_today[clay_today['fav_percent']>clay_today['dog_percent']]
#clay_today=clay_today[clay_today['fav_percent']<clay_today['dog_percent']]

clay_today[['Time','Fav_Top100','Dog_Top100','Fav','fav_rank','fav_rank_high','dog_rank','dog_rank_high','Fav_Odds','fav_percent','Fav_Serve%','Fav_Return%','fav_last_five_win_perc','Dog','Dog_Odds','dog_percent','Dog_Serve%','Dog_Return%','dog_last_five_win_perc']]
clay_today_win_percent=clay_today_win_percent[clay_today_win_percent['Resulted']=='False']
clay_today_win_percent=clay_today_win_percent[clay_today_win_percent['Sex']!='Woxmcens']
clay_today_win_percent[['Time','Fav_Win_Percentage','Fav','Fav_Odds','fav_percent','dog_percent','Dog','Dog_Odds']].sort_values(by=['Fav_Win_Percentage'],ascending=False )
# Out:
#      Time  Fav_Win_Percentage                     Fav  Fav_Odds  fav_percent  \
# 10  21:00            1.000000            Ugo Blanchet      1.85     0.666667
# 4   18:00            0.692308       Raphael Collignon      1.40     0.500000
# 1   19:30            0.615385    Alessandro Giannessi      1.75     0.588235
# 2   23:00            0.615385    Francesco Maestrelli      1.69     0.600000
# 8   19:30            0.500000  Samuel Vincent Ruggeri      1.46     0.666667
# 5   18:00            0.333333  Javier Barranco Cosano      1.64     0.625000
# 6   23:30            0.333333          Norbert Gombos      1.83     0.666667
# 9   19:30            0.333333    Carlos Sanchez Jover      1.53     0.230769
# 11  21:30            0.333333       Marco Trungelliti      1.48     0.583333
# 3   18:00            0.000000         Carlos Taberner      1.62     0.333333
# 7   18:00            0.000000          Giovanni Fonio      1.47     0.500000
#
# ...

# %%
import pandas as pd
from sqlalchemy import create_engine
import pandas as pd
import numpy as np
import datetime
Fav_Win_Percentage=pd.read_pickle('Fav_Win_Percentage_Clay')
devengine = create_engine("sqlite:///C:/Git/tennis_atp/database/bets_sqllite.db")
time_now = datetime.datetime.now()
time_now_formatted = time_now.strftime("%Y-%m-%d")
hard_today=pd.read_pickle('.\Clay_Today')
hard_today['fav_percent_adj'] = np.ceil(hard_today['fav_percent'] * 10) / 10
hard_today['dog_percent_adj'] = np.ceil(hard_today['dog_percent'] * 10) / 10
hard_today_win_percent=pd.merge(hard_today,Fav_Win_Percentage,left_on=['fav_percent_adj','dog_percent_adj'],right_on=['fav_percent_adj','dog_percent_adj'])
hard_today_win_percent=hard_today_win_percent[hard_today_win_percent['Resulted']!='Falxse']
hard_today_win_percent=hard_today_win_percent[hard_today_win_percent['Sex']!='Woxmcens']
hard_today_win_percent[['Time','Fav_Win_Percentage','Fav','Fav_Odds','fav_percent','dog_percent','Dog','Dog_Odds']].sort_values(by=['Time'],ascending=True )#.to_clipboard(index=False)
# Out:
#      Time  Fav_Win_Percentage                     Fav  Fav_Odds  fav_percent  \
# 0   04:10            0.615385      Alexia Todoni Anca      1.66     0.600000
# 3   18:00            0.000000         Carlos Taberner      1.62     0.333333
# 4   18:00            0.692308       Raphael Collignon      1.40     0.500000
# 5   18:00            0.333333  Javier Barranco Cosano      1.64     0.625000
# 7   18:00            0.000000          Giovanni Fonio      1.47     0.500000
# 1   19:30            0.615385    Alessandro Giannessi      1.75     0.588235
# 8   19:30            0.500000  Samuel Vincent Ruggeri      1.46     0.666667
# 9   19:30            0.333333    Carlos Sanchez Jover      1.53     0.230769
# 10  21:00            1.000000            Ugo Blanchet      1.85     0.666667
# 11  21:30            0.333333       Marco Trungelliti      1.48     0.583333
# 2   23:00            0.615385    Francesco Maestrelli      1.69     0.600000
# ...
