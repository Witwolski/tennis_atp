# %%
import pandas as pd
from sqlalchemy import create_engine
import pandas as pd
import numpy as np
import datetime
devengine = create_engine("sqlite:///C:/Git/tennis_atp/database/bets_sqllite.db")
time_now = datetime.datetime.now()
time_now_formatted = time_now.strftime("%Y-%m-%d")
pd.read_sql_query("Select distinct * from results_grass_1 --where date > '2023-04-24'",con=devengine).to_clipboard(index=False)
data=pd.read_clipboard()
data
# Out:
#                    Winner  Winner_Odds  Fav_Odds  Dog_Odds  \
# 0          Juncheng Shang         1.74      1.74      1.99
# 1       Ricardas Berankis         2.22      1.63      2.22
# 2            Marcos Giron         1.63      1.63      2.30
# 3    Veronika Kudermetova         1.22      1.22      4.24
# 4            Greet Minnen         1.38      1.38      3.07
# ..                    ...          ...       ...       ...
# 321          Ilya Ivashka         1.60      1.60      2.32
# 322        Belinda Bencic         1.13      1.13      5.90
# 323        Belinda Bencic         1.13      1.13      5.90
# 324       Karen Khachanov         1.35      1.35      3.19
# 325   Alison Van Uytvanck         2.14      1.70      2.14
#
#                       Fav               Elo_Fav                    Dog  \
# 0          Juncheng Shang          Billy Harris           Billy Harris
# 1          Rinky Hijikata        Rinky Hijikata      Ricardas Berankis
# 2            Marcos Giron          Marcos Giron           Jiri Lehecka
# 3    Veronika Kudermetova  Veronika Kudermetova  Alison Riske Amritraj
# 4            Greet Minnen       Jessika Ponchet        Jessika Ponchet
# ..                    ...                   ...                    ...
# 321          Ilya Ivashka          Ilya Ivashka        Emil Ruusuvuori
# 322        Belinda Bencic       Anna Kalinskaya        Anna Kalinskaya
# 323        Belinda Bencic        Belinda Bencic        Anna Kalinskaya
# 324       Karen Khachanov       Kamil Majchrzak        Kamil Majchrzak
# 325         Elise Mertens         Elise Mertens    Alison Van Uytvanck
#
#      fav_percent  dog_percent     Sex        Date  fav_rank  dog_rank  \
# 0       0.555556     0.400000    Mens  2023-06-12     200.0     355.0
# 1       0.687500     0.368421    Mens  2023-06-12     136.0     217.0
# 2       0.410256     0.578947    Mens  2023-06-12      75.0      41.0
# 3       0.758621     0.529412  Womens  2023-06-12      11.0      85.0
# 4       0.200000     0.384615  Womens  2023-06-12     120.0     123.0
# ..           ...          ...     ...         ...       ...       ...
# 321     0.400000     0.500000    Mens  2022-06-09      49.0      62.0
# 322     0.600000     0.600000  Womens  2022-06-09      17.0      81.0
# 323     0.636364     0.600000  Womens  2022-06-09      17.0      86.0
# 324     0.727273     0.333333    Mens  2022-06-09      23.0      81.0
# 325     0.666667     0.500000  Womens  2022-06-09      29.0      46.0
#
#      Elo_Fav_Elo  Elo_Dog_Elo
# 0    1514.564482  1477.220536
# 1    1641.675737  1558.249339
# 2    1472.190431  1357.261671
# 3    1671.712321  1661.109073
# 4    1557.764224  1420.607993
# ..           ...          ...
# 321  1626.708113  1504.618277
# 322  1565.663195  1565.663195
# 323  1626.708113  1504.618277
# 324  1565.663195  1565.663195
# 325  1588.602175  1565.663195
#
# [326 rows x 15 columns]

# %%
data['fav_win_percent_grt_10'] = data['fav_percent'] > 0.1
data['fav_win_percent_grt_20'] = data['fav_percent'] > 0.2
data['fav_win_percent_grt_30'] = data['fav_percent'] > 0.3
data['fav_win_percent_grt_40'] = data['fav_percent'] > 0.4
data['fav_win_percent_grt_50'] = data['fav_percent'] > 0.5
data['fav_win_percent_grt_60'] = data['fav_percent'] > 0.6
data['fav_win_percent_grt_70'] = data['fav_percent'] > 0.7
data['fav_win_percent_grt_80'] = data['fav_percent'] > 0.8
data['fav_win_percent_grt_90'] = data['fav_percent'] > 0.9
data['fav_win_percent_100'] = data['fav_percent'] == 1.0
data['dog_win_percent_grt_10'] = data['dog_percent'] > 0.1
data['dog_win_percent_grt_20'] = data['dog_percent'] > 0.2
data['dog_win_percent_grt_30'] = data['dog_percent'] > 0.3
data['dog_win_percent_grt_40'] = data['dog_percent'] > 0.4
data['dog_win_percent_grt_50'] = data['dog_percent'] > 0.5
data['dog_win_percent_grt_60'] = data['dog_percent'] > 0.6
data['dog_win_percent_grt_70'] = data['dog_percent'] > 0.7
data['dog_win_percent_grt_80'] = data['dog_percent'] > 0.8
data['dog_win_percent_grt_90'] = data['dog_percent'] > 0.9
data['dog_win_percent_100'] = data['dog_percent'] == 1.0

data['fav_win_percent_lt_10'] = data['fav_percent'] < 0.1
data['fav_win_percent_lt_20'] = data['fav_percent'] < 0.2
data['fav_win_percent_lt_30'] = data['fav_percent'] < 0.3
data['fav_win_percent_lt_40'] = data['fav_percent'] < 0.4
data['fav_win_percent_lt_50'] = data['fav_percent'] < 0.5
data['fav_win_percent_lt_60'] = data['fav_percent'] < 0.6
data['fav_win_percent_lt_70'] = data['fav_percent'] < 0.7
data['fav_win_percent_lt_80'] = data['fav_percent'] < 0.8
data['fav_win_percent_lt_90'] = data['fav_percent'] < 0.9
data['fav_win_percent_0'] = data['fav_percent'] == 0.0

data['dog_win_percent_lt_10'] = data['dog_percent'] < 0.1
data['dog_win_percent_lt_20'] = data['dog_percent'] < 0.2
data['dog_win_percent_lt_30'] = data['dog_percent'] < 0.3
data['dog_win_percent_lt_40'] = data['dog_percent'] < 0.4
data['dog_win_percent_lt_50'] = data['dog_percent'] < 0.5
data['dog_win_percent_lt_60'] = data['dog_percent'] < 0.6
data['dog_win_percent_lt_70'] = data['dog_percent'] < 0.7
data['dog_win_percent_lt_80'] = data['dog_percent'] < 0.8
data['dog_win_percent_lt_90'] = data['dog_percent'] < 0.9
data['dog_win_percent_0'] = data['dog_percent'] == 0.0


# Assuming your DataFrame is called 'data' and the rank columns are 'fav_rank' and 'dog_rank'
data['fav_rank_band'] = pd.cut(data['fav_rank'], bins=list(range(0, 201, 20)), labels=list(range(20, 201, 20)), right=False)
data['dog_rank_band'] = pd.cut(data['dog_rank'], bins=list(range(0, 201, 20)), labels=list(range(20, 201, 20)), right=False)

data['fav_rank_band'] = data['fav_rank_band'].astype(float)
data['dog_rank_band'] = data['dog_rank_band'].astype(float)

for i in range(0, 201, 50):
    data[f'fav_rank_gt_{i}'] = data['fav_rank_band'] > i
    data[f'fav_rank_lt_{i}'] = data['fav_rank_band'] < i

    data[f'dog_rank_gt_{i}'] = data['dog_rank_band'] > i
    data[f'dog_rank_lt_{i}'] = data['dog_rank_band'] < i






data['Winner_']=data['Winner']
data['Winner_IsFav']=data['Winner']==data['Fav']
data['Fav_IsEloFav']=data['Fav']==data['Elo_Fav']
data['Female']=data['Sex']=='Womens'
data['Male']=data['Sex']=='Mens'
raw_data=data
#data=data[(data['Fav_Odds']>1.7)&(data['Fav_Odds']<1.8)]
data=data[['fav_win_percent_grt_10',
       'fav_win_percent_grt_20', 'fav_win_percent_grt_30',
       'fav_win_percent_grt_40', 'fav_win_percent_grt_50',
       'fav_win_percent_grt_60', 'fav_win_percent_grt_70',
       'fav_win_percent_grt_80', 'fav_win_percent_grt_90',
       'fav_win_percent_100',
       'dog_win_percent_grt_20', 'dog_win_percent_grt_30',
       'dog_win_percent_grt_40', 'dog_win_percent_grt_50',
       'dog_win_percent_grt_60', 'dog_win_percent_grt_70',
        'dog_win_percent_grt_90',
       'dog_win_percent_100', 'fav_win_percent_lt_10', 'fav_win_percent_lt_20',
       'fav_win_percent_lt_30', 'fav_win_percent_lt_40',
       'fav_win_percent_lt_50', 'fav_win_percent_lt_60',
       'fav_win_percent_lt_70', 'fav_win_percent_lt_80',
       'fav_win_percent_lt_90', 'fav_win_percent_0', 'dog_win_percent_lt_10',
       'dog_win_percent_lt_20', 'dog_win_percent_lt_30',
       'dog_win_percent_lt_40', 'dog_win_percent_lt_50',
       'dog_win_percent_lt_60', 'dog_win_percent_lt_70',
       'dog_win_percent_lt_80', 'dog_win_percent_lt_90', 'dog_win_percent_0',
        'Winner_IsFav',   'Male', 'fav_rank_gt_0',
 'fav_rank_lt_0',
 'dog_rank_gt_0',
 'dog_rank_lt_0',
 'fav_rank_gt_50',
 'fav_rank_lt_50',
 'dog_rank_gt_50',
 'dog_rank_lt_50',
 'fav_rank_gt_100',
 'fav_rank_lt_100',
 'dog_rank_gt_100',
 'dog_rank_lt_100',
 'fav_rank_gt_150',
 'fav_rank_lt_150',
 'dog_rank_gt_150',
 'dog_rank_lt_150',
 'fav_rank_gt_200',
 'fav_rank_lt_200',
 'dog_rank_gt_200',
 'dog_rank_lt_200','dog_percent']]

datax=data[['Winner_IsFav','fav_win_percent_grt_70',
 'fav_win_percent_lt_60',
 'fav_win_percent_grt_50',
 'fav_win_percent_grt_20',
 'fav_win_percent_lt_20']]

# %%
#model_file2
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

from sklearn.metrics import classification_report

# Step 2: Split the data into features (X) and target (y)
X = data.drop(columns=['Winner_IsFav'])
y = data['Winner_IsFav']

# Step 3: Split the data into training and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# Step 4: Train a logistic regression model
model = LogisticRegression(max_iter=10000000)
model.fit(X_train, y_train)

# Step 5: Make predictions on the test set
y_pred = model.predict(X_test)

# Step 6: Evaluate the model
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)
print(classification_report(y_test, y_pred))

# Get the coefficients or feature importances
feature_importances = model.coef_[0]  # For logistic regression, retrieve the coefficients
# Alternatively, for tree-based models like decision trees or random forests, use feature_importances_ attribute

# Rank the features based on importance
feature_importance_dict = dict(zip(X.columns, feature_importances))
sorted_features = sorted(feature_importance_dict.items(), key=lambda x: x[1], reverse=True)
print("Feature Importance:")
feature_to_keep=[]
for feature, importance in sorted_features:
    if importance>0 or importance<-0:
        feature_to_keep.append(feature)
        print(f"{feature}: {importance}")

from joblib import dump
dump(model, 'model_file2_grass.joblib')
# Out:
# Accuracy: 0.6060606060606061
#               precision    recall  f1-score   support
#
#        False       0.36      0.23      0.28        22
#         True       0.67      0.80      0.73        44
#
#     accuracy                           0.61        66
#    macro avg       0.52      0.51      0.50        66
# weighted avg       0.57      0.61      0.58        66
#
# Feature Importance:
# fav_win_percent_grt_30: 1.0112777785396647
# fav_win_percent_grt_80: 0.9300587449805474
# dog_rank_gt_150: 0.5780149606769971
# dog_win_percent_grt_70: 0.5484084993350458
# dog_rank_gt_0: 0.5446831977970492
# dog_win_percent_lt_10: 0.4805156491259072
# dog_rank_gt_50: 0.48049775214650203
# fav_rank_lt_150: 0.47354981594437984
# fav_rank_gt_100: 0.38768676339834474
# fav_win_percent_lt_40: 0.33834264588823487
# fav_win_percent_lt_50: 0.3039625589480428
# dog_win_percent_0: 0.2924190122920535
# dog_win_percent_lt_70: 0.2657190429593495
# dog_win_percent_lt_40: 0.2526241763017386
# fav_win_percent_grt_90: 0.2511241222395217
# fav_rank_lt_50: 0.24079560555365703
# dog_win_percent_grt_50: 0.2397321157822417
# fav_rank_gt_0: 0.23102485921092822
# fav_win_percent_grt_10: 0.22919219848436898
# fav_win_percent_100: 0.18400510246374288
# fav_win_percent_lt_30: 0.16212857870446756
# Male: 0.10016288566513348
# dog_win_percent_lt_30: 0.09961780927386027
# dog_win_percent_grt_30: 0.0905775896163099
# dog_rank_lt_50: 0.06418544565054844
# fav_win_percent_grt_60: 0.054773878045596684
# dog_rank_lt_200: 0.02670095304974613
# fav_rank_lt_200: 0.021510204938567118
# dog_win_percent_lt_90: 0.0195369708685365
# dog_win_percent_lt_60: 0.0030865528392349734
# dog_win_percent_grt_40: -0.0019908695257875382
# fav_rank_gt_50: -0.0097707463427288
# dog_win_percent_grt_90: -0.01945910145163114
# dog_win_percent_100: -0.01945910145163114
# dog_rank_lt_150: -0.03333176287994691
# fav_win_percent_grt_70: -0.06300245172142134
# dog_percent: -0.1132605977700225
# dog_win_percent_lt_50: -0.1215338798637988
# fav_rank_lt_100: -0.13311740968274904
# fav_win_percent_grt_50: -0.13702797178165874
# fav_win_percent_grt_40: -0.14146139343664965
# fav_win_percent_lt_10: -0.22911432906746393
# fav_win_percent_0: -0.22911432906746393
# fav_win_percent_lt_60: -0.23550875147027225
# fav_rank_gt_150: -0.24252495673345012
# dog_rank_lt_100: -0.2503710491909486
# fav_win_percent_lt_20: -0.34432545916831675
# fav_win_percent_lt_90: -0.3556097718208377
# dog_win_percent_grt_20: -0.3665110164954951
# fav_win_percent_lt_80: -0.3706502357828551
# dog_win_percent_lt_20: -0.37194549032162366
# dog_win_percent_lt_80: -0.4352060825487797
# dog_rank_gt_100: -0.4823305632287376
# fav_win_percent_grt_20: -0.5045762483122572
# fav_win_percent_lt_70: -0.6406418644317733
# dog_win_percent_grt_60: -0.9255119464299001
# ['model_file2_grass.joblib']

# %%
#raw_data[raw_data['Sex']=='Womens']
for x in range(140,200,10):
    y=x+10
    #for y in range(105,205,5):
    lower=x/100
    higher=y/100
    print(lower,higher)
    filter=raw_data[(raw_data['Fav_Odds']>=lower)&(raw_data['Fav_Odds']<=higher)]
    for feature in feature_to_keep:    
        test=filter[filter[feature]==True]
        
        if len(test)>10:
            perc=(len(test[test['Winner_IsFav']==True])/len(test))
            
            if perc>0.7:
                
                print(feature," ({:.1%})".format(len(test[test['Winner_IsFav']==True])/len(test)),len(test))
                #print("{:.1%}".format(len(test[test['Winner_IsFav']==True])/len(test)),len(test))
# Out:
# 1.4 1.5
# dog_rank_gt_50  (73.2%) 41
# fav_rank_lt_150  (72.9%) 48
# fav_win_percent_lt_50  (71.4%) 21
# dog_win_percent_lt_40  (75.0%) 16
# fav_rank_lt_200  (71.4%) 49
# fav_rank_gt_50  (73.1%) 26
# fav_rank_lt_100  (72.5%) 40
# dog_rank_gt_100  (75.0%) 12
# 1.5 1.6
# 1.6 1.7
# fav_rank_gt_100  (81.8%) 11
# fav_win_percent_lt_50  (79.2%) 24
# dog_rank_lt_50  (72.7%) 11
# 1.7 1.8
# 1.8 1.9
# 1.9 2.0

# %%
raw_data
# Out:
#                    Winner  Winner_Odds  Fav_Odds  Dog_Odds  \
# 0          Juncheng Shang         1.74      1.74      1.99
# 1       Ricardas Berankis         2.22      1.63      2.22
# 2            Marcos Giron         1.63      1.63      2.30
# 3    Veronika Kudermetova         1.22      1.22      4.24
# 4            Greet Minnen         1.38      1.38      3.07
# ..                    ...          ...       ...       ...
# 321          Ilya Ivashka         1.60      1.60      2.32
# 322        Belinda Bencic         1.13      1.13      5.90
# 323        Belinda Bencic         1.13      1.13      5.90
# 324       Karen Khachanov         1.35      1.35      3.19
# 325   Alison Van Uytvanck         2.14      1.70      2.14
#
#                       Fav               Elo_Fav                    Dog  \
# 0          Juncheng Shang          Billy Harris           Billy Harris
# 1          Rinky Hijikata        Rinky Hijikata      Ricardas Berankis
# 2            Marcos Giron          Marcos Giron           Jiri Lehecka
# 3    Veronika Kudermetova  Veronika Kudermetova  Alison Riske Amritraj
# 4            Greet Minnen       Jessika Ponchet        Jessika Ponchet
# ..                    ...                   ...                    ...
# 321          Ilya Ivashka          Ilya Ivashka        Emil Ruusuvuori
# 322        Belinda Bencic       Anna Kalinskaya        Anna Kalinskaya
# 323        Belinda Bencic        Belinda Bencic        Anna Kalinskaya
# 324       Karen Khachanov       Kamil Majchrzak        Kamil Majchrzak
# 325         Elise Mertens         Elise Mertens    Alison Van Uytvanck
#
#      fav_percent  dog_percent     Sex  ... dog_rank_lt_150  fav_rank_gt_200  \
# 0       0.555556     0.400000    Mens  ...           False            False
# 1       0.687500     0.368421    Mens  ...           False            False
# 2       0.410256     0.578947    Mens  ...            True            False
# 3       0.758621     0.529412  Womens  ...            True            False
# 4       0.200000     0.384615  Womens  ...            True            False
# ..           ...          ...     ...  ...             ...              ...
# 321     0.400000     0.500000    Mens  ...            True            False
# 322     0.600000     0.600000  Womens  ...            True            False
# 323     0.636364     0.600000  Womens  ...            True            False
# 324     0.727273     0.333333    Mens  ...            True            False
# 325     0.666667     0.500000  Womens  ...            True            False
#
#      fav_rank_lt_200  dog_rank_gt_200  dog_rank_lt_200               Winner_  \
# 0              False            False            False        Juncheng Shang
# 1               True            False            False     Ricardas Berankis
# 2               True            False             True          Marcos Giron
# 3               True            False             True  Veronika Kudermetova
# 4               True            False             True          Greet Minnen
# ..               ...              ...              ...                   ...
# 321             True            False             True          Ilya Ivashka
# 322             True            False             True        Belinda Bencic
# 323             True            False             True        Belinda Bencic
# 324             True            False             True       Karen Khachanov
# 325             True            False             True   Alison Van Uytvanck
#
#      Winner_IsFav  Fav_IsEloFav  Female   Male
# 0            True         False   False   True
# 1           False          True   False   True
# 2            True          True   False   True
# 3            True          True    True  False
# 4            True         False    True  False
# ..            ...           ...     ...    ...
# 321          True          True   False   True
# 322          True         False    True  False
# 323          True          True    True  False
# 324          True         False   False   True
# 325         False          True    True  False
#
# [326 rows x 82 columns]

# %%
filter=raw_data[(raw_data['Fav_Odds']>=1.2)&(raw_data['Fav_Odds']<=1.3)&(raw_data['Sex']=='Mens')]
  
test=filter[(filter['fav_rank_gt_50']==False)]
test=test[(test['dog_rank_gt_50']==False)&(test['fav_win_percent_grt_70']==True)&(test['dog_win_percent_grt_60']==True)]
        
if len(test)>1:
    perc=(len(test[test['Winner_IsFav']==True])/len(test))
    
        
    print(" ({:.1%})".format(len(test[test['Winner_IsFav']==True])/len(test)),len(test))
    #print("{:.1%}".format(len(test[test['Winner_IsFav']==True])/len(test)),len(test))
