# %%
import pandas as pd
from sqlalchemy import create_engine
import pandas as pd
import numpy as np
import datetime
devengine = create_engine("sqlite:///C:/Git/tennis_atp/database/bets_sqllite.db")
time_now = datetime.datetime.now()
time_now_formatted = time_now.strftime("%Y-%m-%d")
data=pd.read_sql_query("Select distinct * from results_hard_1 --where date > '2023-04-24'",con=devengine)
data["Fav_Odds"] = data.Fav_Odds.astype(float)
data["Dog_Odds"] = data.Dog_Odds.astype(float)

# %%
data['fav_win_percent_grt_10'] = data['fav_percent'] > 0.1
data['fav_win_percent_grt_20'] = data['fav_percent'] > 0.2
data['fav_win_percent_grt_30'] = data['fav_percent'] > 0.3
data['fav_win_percent_grt_40'] = data['fav_percent'] > 0.4
data['fav_win_percent_grt_50'] = data['fav_percent'] > 0.5
data['fav_win_percent_grt_60'] = data['fav_percent'] > 0.6
data['fav_win_percent_grt_70'] = data['fav_percent'] > 0.7
data['fav_win_percent_grt_80'] = data['fav_percent'] > 0.8
data['fav_win_percent_grt_90'] = data['fav_percent'] > 0.9
data['fav_win_percent_100'] = data['fav_percent'] == 1.0
data['dog_win_percent_grt_10'] = data['dog_percent'] > 0.1
data['dog_win_percent_grt_20'] = data['dog_percent'] > 0.2
data['dog_win_percent_grt_30'] = data['dog_percent'] > 0.3
data['dog_win_percent_grt_40'] = data['dog_percent'] > 0.4
data['dog_win_percent_grt_50'] = data['dog_percent'] > 0.5
data['dog_win_percent_grt_60'] = data['dog_percent'] > 0.6
data['dog_win_percent_grt_70'] = data['dog_percent'] > 0.7
data['dog_win_percent_grt_80'] = data['dog_percent'] > 0.8
data['dog_win_percent_grt_90'] = data['dog_percent'] > 0.9
data['dog_win_percent_100'] = data['dog_percent'] == 1.0

data['fav_win_percent_lt_10'] = data['fav_percent'] < 0.1
data['fav_win_percent_lt_20'] = data['fav_percent'] < 0.2
data['fav_win_percent_lt_30'] = data['fav_percent'] < 0.3
data['fav_win_percent_lt_40'] = data['fav_percent'] < 0.4
data['fav_win_percent_lt_50'] = data['fav_percent'] < 0.5
data['fav_win_percent_lt_60'] = data['fav_percent'] < 0.6
data['fav_win_percent_lt_70'] = data['fav_percent'] < 0.7
data['fav_win_percent_lt_80'] = data['fav_percent'] < 0.8
data['fav_win_percent_lt_90'] = data['fav_percent'] < 0.9
data['fav_win_percent_0'] = data['fav_percent'] == 0.0

data['dog_win_percent_lt_10'] = data['dog_percent'] < 0.1
data['dog_win_percent_lt_20'] = data['dog_percent'] < 0.2
data['dog_win_percent_lt_30'] = data['dog_percent'] < 0.3
data['dog_win_percent_lt_40'] = data['dog_percent'] < 0.4
data['dog_win_percent_lt_50'] = data['dog_percent'] < 0.5
data['dog_win_percent_lt_60'] = data['dog_percent'] < 0.6
data['dog_win_percent_lt_70'] = data['dog_percent'] < 0.7
data['dog_win_percent_lt_80'] = data['dog_percent'] < 0.8
data['dog_win_percent_lt_90'] = data['dog_percent'] < 0.9
data['dog_win_percent_0'] = data['dog_percent'] == 0.0


# Assuming your DataFrame is called 'data' and the rank columns are 'fav_rank' and 'dog_rank'
data['fav_rank_band'] = pd.cut(data['fav_rank'], bins=list(range(0, 201, 20)), labels=list(range(20, 201, 20)), right=False)
data['dog_rank_band'] = pd.cut(data['dog_rank'], bins=list(range(0, 201, 20)), labels=list(range(20, 201, 20)), right=False)

data['fav_rank_band'] = data['fav_rank_band'].astype(float)
data['dog_rank_band'] = data['dog_rank_band'].astype(float)

for i in range(0, 201, 50):
    data[f'fav_rank_gt_{i}'] = data['fav_rank_band'] > i
    data[f'fav_rank_lt_{i}'] = data['fav_rank_band'] < i

    data[f'dog_rank_gt_{i}'] = data['dog_rank_band'] > i
    data[f'dog_rank_lt_{i}'] = data['dog_rank_band'] < i






data['Winner_']=data['Winner']
data['Winner_IsFav']=data['Winner']==data['Fav']
data['Fav_IsEloFav']=data['Fav']==data['Elo_Fav']
data['Female']=data['Sex']=='Womens'
data['Male']=data['Sex']=='Mens'
raw_data=data
data=data[(data['Fav_Odds']>=1.7)&(data['Fav_Odds']<=1.8)]
data=data[['fav_win_percent_grt_10',
       'fav_win_percent_grt_20', 'fav_win_percent_grt_30',
       'fav_win_percent_grt_40', 'fav_win_percent_grt_50',
       'fav_win_percent_grt_60', 'fav_win_percent_grt_70',
       'fav_win_percent_grt_80', 'fav_win_percent_grt_90',
       'fav_win_percent_100',
       'dog_win_percent_grt_20', 'dog_win_percent_grt_30',
       'dog_win_percent_grt_40', 'dog_win_percent_grt_50',
       'dog_win_percent_grt_60', 'dog_win_percent_grt_70',
        'dog_win_percent_grt_90',
       'dog_win_percent_100', 'fav_win_percent_lt_10', 'fav_win_percent_lt_20',
       'fav_win_percent_lt_30', 'fav_win_percent_lt_40',
       'fav_win_percent_lt_50', 'fav_win_percent_lt_60',
       'fav_win_percent_lt_70', 'fav_win_percent_lt_80',
       'fav_win_percent_lt_90', 'fav_win_percent_0', 'dog_win_percent_lt_10',
       'dog_win_percent_lt_20', 'dog_win_percent_lt_30',
       'dog_win_percent_lt_40', 'dog_win_percent_lt_50',
       'dog_win_percent_lt_60', 'dog_win_percent_lt_70',
       'dog_win_percent_lt_80', 'dog_win_percent_lt_90', 'dog_win_percent_0',
        'Winner_IsFav',   'Male', 'fav_rank_gt_0',
 'fav_rank_lt_0',
 'dog_rank_gt_0',
 'dog_rank_lt_0',
 'fav_rank_gt_50',
 'fav_rank_lt_50',
 'dog_rank_gt_50',
 'dog_rank_lt_50',
 'fav_rank_gt_100',
 'fav_rank_lt_100',
 'dog_rank_gt_100',
 'dog_rank_lt_100',
 'fav_rank_gt_150',
 'fav_rank_lt_150',
 'dog_rank_gt_150',
 'dog_rank_lt_150',
 'fav_rank_gt_200',
 'fav_rank_lt_200',
 'dog_rank_gt_200',
 'dog_rank_lt_200','dog_percent','Fav_Top100','Dog_Top100']]

datax=data[['Winner_IsFav','fav_win_percent_grt_70',
 'fav_win_percent_lt_60',
 'fav_win_percent_grt_50',
 'fav_win_percent_grt_20',
 'fav_win_percent_lt_20']]

# %%
#raw_data[raw_data['Sex']=='Womens']
for x in range(180,200,10):
    y=x+10
    #for y in range(105,205,5):
    lower=x/100
    higher=y/100
    print(lower,higher)
    filter=raw_data[(raw_data['Fav_Odds']>=lower)&(raw_data['Fav_Odds']<=higher)]
    for feature in filter.columns:    
        test=filter[filter[feature]==True]
        
        if len(test)>50 and feature != 'Winner_IsFav':
            perc=(len(test[test['Winner_IsFav']==True])/len(test))
            
            if perc>0.54:
                
                print(feature," ({:.1%})".format(len(test[test['Winner_IsFav']==True])/len(test)),len(test))
                #print("{:.1%}".format(len(test[test['Winner_IsFav']==True])/len(test)),len(test))
# Out:
# 1.8 1.9
# fav_win_percent_lt_50  (54.7%) 95
# fav_rank_lt_50  (57.6%) 59
# dog_rank_lt_50  (59.3%) 54
# fav_rank_lt_100  (56.1%) 123
# dog_rank_lt_100  (55.1%) 118
# fav_rank_lt_150  (55.3%) 197
# 1.9 2.0

# %%
#raw_data[raw_data['Sex']=='Womens']
for x in range(120,200,10):
    y=x+10
    #for y in range(105,205,5):
    lower=x/100
    higher=y/100
    print(lower,higher)
    filter=raw_data[(raw_data['Fav_Odds']>=lower)&(raw_data['Fav_Odds']<=higher)]
    for feature in filter.columns:    
        test=filter[filter[feature]==True]
        
        if len(test)>100 and feature != 'Winner_IsFav':
            perc=(len(test[test['Winner_IsFav']==True])/len(test))
            
            if perc>0.7:
                
                print(feature," ({:.1%})".format(len(test[test['Winner_IsFav']==True])/len(test)),len(test))
                #print("{:.1%}".format(len(test[test['Winner_IsFav']==True])/len(test)),len(test))
# Out:
# 1.2 1.3
# fav_win_percent_grt_10  (77.2%) 580
# fav_win_percent_grt_20  (77.4%) 579
# fav_win_percent_grt_30  (77.2%) 575
# fav_win_percent_grt_40  (76.9%) 540
# fav_win_percent_grt_50  (76.5%) 468
# fav_win_percent_grt_60  (76.5%) 378
# fav_win_percent_grt_70  (76.4%) 242
# fav_win_percent_grt_80  (78.8%) 113
# dog_win_percent_grt_10  (76.7%) 554
# dog_win_percent_grt_20  (76.7%) 502
# dog_win_percent_grt_30  (75.9%) 423
# dog_win_percent_grt_40  (76.1%) 297
# dog_win_percent_grt_50  (77.6%) 170
# fav_win_percent_lt_60  (78.1%) 151
# fav_win_percent_lt_70  (78.3%) 277
# fav_win_percent_lt_80  (77.2%) 413
# fav_win_percent_lt_90  (77.6%) 518
# dog_win_percent_lt_30  (80.2%) 111
# dog_win_percent_lt_40  (77.6%) 205
# dog_win_percent_lt_50  (78.3%) 337
# dog_win_percent_lt_60  (77.4%) 452
# dog_win_percent_lt_70  (77.7%) 533
# dog_win_percent_lt_80  (77.5%) 559
# dog_win_percent_lt_90  (77.3%) 578
# fav_rank_gt_0  (76.6%) 505
# dog_rank_gt_0  (73.8%) 321
# fav_rank_gt_50  (77.8%) 284
# fav_rank_lt_50  (75.1%) 221
# dog_rank_gt_50  (74.0%) 254
# fav_rank_gt_100  (78.8%) 179
# fav_rank_lt_100  (75.3%) 287
# dog_rank_gt_100  (70.3%) 118
# dog_rank_lt_100  (74.4%) 160
# fav_rank_lt_150  (77.5%) 426
# dog_rank_lt_150  (74.5%) 251
# fav_rank_lt_200  (76.5%) 486
# dog_rank_lt_200  (74.3%) 296
# Fav_IsEloFav  (78.3%) 503
# Female  (74.0%) 146
# Male  (78.3%) 434
# 1.3 1.4
# fav_win_percent_grt_10  (71.4%) 665
# fav_win_percent_grt_20  (71.3%) 659
# fav_win_percent_grt_30  (71.0%) 644
# fav_win_percent_grt_40  (71.2%) 598
# fav_win_percent_grt_50  (70.8%) 504
# fav_win_percent_grt_60  (73.8%) 363
# fav_win_percent_grt_70  (73.9%) 218
# dog_win_percent_grt_10  (71.6%) 651
# dog_win_percent_grt_20  (71.0%) 594
# dog_win_percent_grt_40  (70.5%) 356
# dog_win_percent_grt_50  (71.9%) 199
# dog_win_percent_grt_60  (76.2%) 105
# fav_win_percent_lt_50  (73.3%) 101
# fav_win_percent_lt_60  (71.9%) 242
# fav_win_percent_lt_70  (70.1%) 381
# fav_win_percent_lt_80  (71.1%) 530
# fav_win_percent_lt_90  (70.9%) 622
# dog_win_percent_lt_40  (76.3%) 207
# dog_win_percent_lt_50  (72.6%) 379
# dog_win_percent_lt_60  (70.9%) 508
# dog_win_percent_lt_70  (71.5%) 608
# dog_win_percent_lt_80  (71.5%) 643
# dog_win_percent_lt_90  (71.6%) 665
# fav_rank_gt_0  (71.9%) 551
# dog_rank_gt_0  (71.5%) 386
# fav_rank_gt_50  (73.1%) 342
# dog_rank_gt_50  (71.7%) 315
# fav_rank_lt_100  (74.4%) 308
# dog_rank_lt_100  (72.4%) 196
# fav_rank_lt_150  (72.2%) 468
# dog_rank_lt_150  (72.1%) 301
# fav_rank_lt_200  (72.2%) 533
# dog_rank_lt_200  (71.6%) 356
# Fav_IsEloFav  (71.9%) 538
# Male  (72.0%) 493
# 1.4 1.5
# 1.5 1.6
# 1.6 1.7
# 1.7 1.8
# 1.8 1.9
# 1.9 2.0

# %%
lower=1.5
higher=2
print(lower,higher)
filter=raw_data[(raw_data['Fav_Odds']>=lower)&(raw_data['Fav_Odds']<=higher)]
for feature in filter.columns:    
    test=filter[filter[feature]==True]
    
    if len(test)>10 and feature != 'Winner_IsFav':
        perc=(len(test[test['Winner_IsFav']==True])/len(test))
        
        if perc>0.6:
            
            print(feature," ({:.1%})".format(len(test[test['Winner_IsFav']==True])/len(test)),len(test))
            #print("{:.1%}".format(len(test[test['Winner_IsFav']==True])/len(test)),len(test))
# Out:
# 1.5 2
# dog_win_percent_grt_80  (65.1%) 43
# dog_win_percent_lt_10  (83.3%) 12
# dog_win_percent_lt_20  (67.9%) 56
# fav_rank_lt_50  (62.0%) 410
# dog_rank_lt_50  (60.1%) 278

# %%
lower=1
higher=2
print(lower,higher)
filter=raw_data[(raw_data['Fav_Odds']>=lower)&(raw_data['Fav_Odds']<=higher)]
filter1=filter['fav_win_percent_grt_60']
filter2=filter['dog_win_percent_lt_20']
test=filter[filter1&filter2]

if len(test)>1:
    perc=(len(test[test['Winner_IsFav']==True])/len(test))
    
    if perc>0:
        
        print("({:.1%})".format(len(test[test['Winner_IsFav']==True])/len(test)),len(test))
        #print("{:.1%}".format(len(test[test['Winner_IsFav']==True])/len(test)),len(test))
# Out:
# 1 2
# (80.6%) 67

# %%
test
# Out:
#      Winner_Odds              Winner  Fav_Odds  Dog_Odds  \
# 59           2.5          Aidan Mayo      1.51      2.50
# 149         1.26        Jiri Lehecka      1.26      3.83
# 166         2.31          Aidan Mayo      1.58      2.31
# 299         1.23       Arthur Cazaux      1.23      3.97
# 318         1.23          Luca Nardi      1.23      3.99
# ...          ...                 ...       ...       ...
# 4100        1.28    Alexis Galarneau      1.28      3.51
# 4248        3.61      Nathan Ponwith      1.25      3.61
# 4339        3.06   Antoine Escoffier      1.34      3.06
# 4359        1.83       Alfredo Perez      1.83      1.86
# 4370        1.22  Yoshihito Nishioka      1.22      4.04
#
#                              Fav                     Elo_Fav  Fav_Games  \
# 59    Giovanni Mpetshi Perricard  Giovanni Mpetshi Perricard         10
# 149                 Jiri Lehecka                Jiri Lehecka         11
# 166     Frederico Ferreira Silva                  Aidan Mayo         11
# 299                Arthur Cazaux               Arthur Cazaux         11
# 318                   Luca Nardi                  Luca Nardi         11
# ...                          ...                         ...        ...
# 4100            Alexis Galarneau            Alexis Galarneau         11
# 4248             August Holmgren             August Holmgren          7
# 4339             Mattia Bellucci             Mattia Bellucci         10
# 4359               Alfredo Perez               Alfredo Perez          6
# 4370          Yoshihito Nishioka          Yoshihito Nishioka         10
#
#                     Dog  Dog_Games  fav_percent  ...  dog_rank_lt_150  \
# 59           Aidan Mayo         11     0.800000  ...            False
# 149    Mitchell Krueger         10     0.727273  ...            False
# 166          Aidan Mayo         10     0.636364  ...            False
# 299       Ulises Blanch         10     0.909091  ...            False
# 318          Aidan Mayo         10     0.818182  ...            False
# ...                 ...        ...          ...  ...              ...
# 4100   Skander Mansouri          5     0.727273  ...            False
# 4248     Nathan Ponwith          6     0.714286  ...            False
# 4339  Antoine Escoffier          6     1.000000  ...            False
# 4359      Ezekiel Clark          6     0.666667  ...            False
# 4370         Joao Sousa          6     0.800000  ...             True
#
#      fav_rank_gt_200 fav_rank_lt_200  dog_rank_gt_200  dog_rank_lt_200  \
# 59             False           False            False            False
# 149            False            True            False            False
# 166            False           False            False            False
# 299            False            True            False            False
# 318            False            True            False            False
# ...              ...             ...              ...              ...
# 4100           False           False            False            False
# 4248           False           False            False            False
# 4339           False            True            False            False
# 4359           False           False            False            False
# 4370           False            True            False             True
#
#                  Winner_  Winner_IsFav  Fav_IsEloFav  Female  Male
# 59            Aidan Mayo         False          True   False  True
# 149         Jiri Lehecka          True          True   False  True
# 166           Aidan Mayo         False         False   False  True
# 299        Arthur Cazaux          True          True   False  True
# 318           Luca Nardi          True          True   False  True
# ...                  ...           ...           ...     ...   ...
# 4100    Alexis Galarneau          True          True   False  True
# 4248      Nathan Ponwith         False          True   False  True
# 4339   Antoine Escoffier         False          True   False  True
# 4359       Alfredo Perez          True          True   False  True
# 4370  Yoshihito Nishioka          True          True   False  True
#
# [67 rows x 86 columns]
