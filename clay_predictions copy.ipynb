# %%
import pandas as pd
from sqlalchemy import create_engine
import pandas as pd
import numpy as np
import datetime
devengine = create_engine("sqlite:///C:/Git/tennis_atp/database/bets_sqllite.db")
time_now = datetime.datetime.now()
time_now_formatted = time_now.strftime("%Y-%m-%d")
clay_today=pd.read_pickle('.\Hard_Today')
clay_today=clay_today[clay_today['Resulted']=='False']

# %%
clay_today[['Time','Fav','Fav_Odds','dog_percent','fav_percent','fav_last_five_win_perc','dog_last_five_win_perc']][((clay_today['fav_percent']>0.8)|(clay_today['dog_percent']>0.4)
                                                            )&(clay_today['Fav_Odds']<12)&(clay_today['Fav_Odds']>1.2)]
# Out:
#      Time                        Fav  Fav_Odds  dog_percent  fav_percent  \
# 0   01:00               Taylor Fritz      1.32     0.428571     0.738095
# 3   01:00              Andrey Rublev      1.25     0.451613     0.760000
# 4   02:30         Liudmila Samsonova      1.70     0.551724     0.684211
# 7   02:30            Daria Kasatkina      1.29     0.454545     0.514286
# 10  02:30             Hubert Hurkacz      1.33     0.560000     0.666667
# 12  04:00         Stefanos Tsitsipas      1.28     0.600000     0.700000
# 15  04:00           Karolina Muchova      1.48     0.480000     0.619048
# 18  05:30  Nicolas Moreno De Alboran      1.44     0.666667     0.700000
# 20  05:30           Leylah Fernandez      1.85     0.625000     0.235294
# 22  07:00                 Tommy Paul      1.53     0.470588     0.515152
# 26  09:00              Maria Sakkari      1.58     0.454545     0.622222
# 28  10:30              Petra Kvitova      1.79     0.538462     0.681818
# 29  18:00               Greet Minnen      1.56     0.454545     0.300000
#
#     fav_last_five_win_perc  dog_last_five_win_perc
# 0                      0.8                     0.6
# 3                      0.6                     0.6
# 4                      0.6                     0.4
# 7                      0.4                     0.4
# 10                     0.4                     0.4
# 12                     0.8                     0.6
# 15                     0.8                     0.6
# 18                     0.6                     0.8
# 20                     0.6                     0.4
# 22                     0.6                     0.8
# 26                     0.6                     0.6
# 28                     1.0                     0.6
# 29                     0.4                     0.4

# %%
import pandas as pd
from sqlalchemy import create_engine
import pandas as pd
import numpy as np
import datetime
devengine = create_engine("sqlite:///C:/Git/tennis_atp/database/bets_sqllite.db")
time_now = datetime.datetime.now()
time_now_formatted = time_now.strftime("%Y-%m-%d")
clay_today=pd.read_pickle('.\Hard_Today')
clay_today=clay_today[clay_today['Resulted']=='False']

# %%
clay_today[['Time','Fav_Top100','Dog_Top100','Fav','Fav_Odds','dog_percent','fav_percent','fav_last_five_win_perc','dog_last_five_win_perc']][((clay_today['fav_percent']>0.7)|(clay_today['dog_percent']>0.4)
                                                            )&(clay_today['Fav_Odds']<12)&(clay_today['Fav_Odds']>1.2)]
# Out:
#      Time  Fav_Top100  Dog_Top100                        Fav  Fav_Odds  \
# 0   01:00         0.8         0.5               Taylor Fritz      1.32
# 3   01:00         0.7         0.5              Andrey Rublev      1.25
# 4   02:30         0.7         0.6         Liudmila Samsonova      1.70
# 7   02:30         0.5         0.6            Daria Kasatkina      1.29
# 10  02:30         0.7         0.6             Hubert Hurkacz      1.33
# 12  04:00         0.6         0.5         Stefanos Tsitsipas      1.28
# 14  04:00         0.6         0.3             Alex De Minaur      1.22
# 15  04:00         0.6         0.5           Karolina Muchova      1.48
# 17  05:30         0.7         0.5              Jannik Sinner      1.49
# 18  05:30         0.0         0.0  Nicolas Moreno De Alboran      1.44
# 19  05:30         0.2         0.0             Rinky Hijikata      1.46
# 20  05:30         0.4         0.5           Leylah Fernandez      1.85
# 22  07:00         0.6         0.5                 Tommy Paul      1.53
# 23  07:30         0.6         0.5            Sebastian Korda      1.41
# 26  09:00         0.6         0.5              Maria Sakkari      1.58
# 27  10:30         0.6         0.4                Holger Rune      1.30
# 28  10:30         0.7         0.6              Petra Kvitova      1.79
# 29  18:00         0.2         0.0               Greet Minnen      1.56
#
#     dog_percent  fav_percent  fav_last_five_win_perc  dog_last_five_win_perc
# 0      0.428571     0.738095                     0.8                     0.6
# 3      0.451613     0.760000                     0.6                     0.6
# 4      0.551724     0.684211                     0.6                     0.4
# 7      0.454545     0.514286                     0.4                     0.4
# 10     0.560000     0.666667                     0.4                     0.4
# 12     0.600000     0.700000                     0.8                     0.6
# 14     0.200000     0.800000                     0.8                     0.4
# 15     0.480000     0.619048                     0.8                     0.6
# 17     0.384615     0.710526                     0.8                     0.6
# 18     0.666667     0.700000                     0.6                     0.8
# 19     0.333333     0.750000                     0.4                     0.4
# 20     0.625000     0.235294                     0.6                     0.4
# 22     0.470588     0.515152                     0.6                     0.8
# 23     0.363636     0.718750                     0.6                     0.4
# 26     0.454545     0.622222                     0.6                     0.6
# 27     0.304348     0.764706                     0.6                     0.4
# 28     0.538462     0.681818                     1.0                     0.6
# 29     0.454545     0.300000                     0.4                     0.4
