# %%
#Fav / Dog Win percentage + odds filter
import pandas as pd
from sqlalchemy import create_engine
import pandas as pd
import numpy as np
import datetime

#data=data[(data['Fav_Odds']>=1.3)&(data['Fav_Odds']<=1.4)]

odds_filter=1.7
devengine = create_engine("sqlite:///C:/Git/tennis_atp/database/bets_sqllite.db")
time_now = datetime.datetime.now()
def hist_data(surface, sex, odds_filter):
    data=pd.read_sql_query(f"Select distinct * from results_{surface}_1 where date > '2024-01-01' ",con=devengine)#.to_clipboard(index=False)
    time_now_formatted = time_now.strftime("%Y-%m-%d")
    data["Fav_Odds"] = data.Fav_Odds.astype(float)
    data["Dog_Odds"] = data.Dog_Odds.astype(float)
    data['Fav_Win'] = data['Winner']==data['Fav']
    data=data#[(data['Fav_Odds']>=odds_filter)&(data['Fav_Odds']<=odds_filter+0.1)]
    #print(odds_filter+0.1)
    data=data[data['Sex']==sex]
    return data
    
def test_1(df,surface,sex):
    #womens clay
    filtered=df[(df['dog_percent']>0.2)&(df['fav_percent']<1)&(df['Fav_Odds']>=1.5)&(df['Fav_Odds']<=1.6)] #womens clay 52% odds 1.5
    #womens hard
    filtered1=((df['dog_percent']>0.5)&(df['fav_percent']<1)&(df['Fav_Odds']>=1.7)&(df['Fav_Odds']<=1.8)) #womens clay 53% odds 1.7
    filtered2=((df['dog_percent']>0.5)&(df['fav_percent']<0.6)&(df['Fav_Odds']>=1.7)&(df['Fav_Odds']<=1.8)) #womens clay 59% odds 1.7
    filtered3=((df['dog_percent']>0.5)&(df['fav_percent']<5)&(df['Fav_Odds']>=1.7)&(df['Fav_Odds']<=1.8)) #womens clay 59% odds 1.7
    filtered4=((df['dog_percent']>0)&(df['fav_percent']<0.5)&(df['Fav_Top100']<0.5)&(df['Fav_Odds']>=1.5)&(df['Fav_Odds']<=1.6)) #hard 1.5 odds
    filtered5=((df['dog_percent']>0)&(df['fav_percent']<0.5)&(df['Dog_Games']>10)&(df['Fav_Games']>10)&(df['Fav_Odds']>=1.5)&(df['Fav_Odds']<=1.9)) #1.5 - 1.9
    filtered6=((df['dog_percent']>0.5)&(df['fav_percent']<5)&(df['Dog_Games']>10)&(df['Fav_Games']>10)&(df['Fav_Odds']>=1.6)&(df['Fav_Odds']<=1.9))
    filtered7=((df['Dog_Top100']>0.4)&(df['fav_percent']<5)&(df['Dog_Games']>10)&(df['Fav_Games']>10)&(df['Fav_Odds']>=1.6)&(df['Fav_Odds']<=1.9)) #1.6 - 1.9
    filtered8=((df['Fav_Top100']<0.5)&(df['fav_percent']<5)&(df['Dog_Games']>10)&(df['Fav_Games']>10)&(df['Fav_Odds']>=1.5)&(df['Fav_Odds']<=1.9)) #1.5 - 1.9
    filtered21=((df['dog_percent']>0.5)&(df['fav_percent']<1)&(df['dog_rank']<=100)&(df['Fav_Odds']>=1.6)&(df['Fav_Odds']<=1.8)) #hard womens odds 1.6,1.7
    filtered22=((df['dog_percent']>0)&(df['fav_percent']<1)&(df['dog_rank']<=100)&(df['Fav_Odds']>=1.7)&(df['Fav_Odds']<=1.8)) #hard womens odds 1.7
    filtered23=((df['dog_percent']>0)&(df['fav_percent']<0.5)&(df['dog_rank']<=100)&(df['Fav_Odds']>=1.6)&(df['Fav_Odds']<=1.7)) #hard womens odds 1.6
    filtered24=((df['dog_percent']>0.5)&(df['fav_percent']<5)&(df['dog_rank']<=100)&(df['Fav_Odds']>=1.6)&(df['Fav_Odds']<=1.8)) #hard womens odds 1.6, 1.7
    filtered25=((df['dog_percent']>0.5)&(df['fav_percent']<5)&(df['dog_rank']<=200)&(df['Fav_Odds']>=1.7)&(df['Fav_Odds']<=1.8)) #hard womens odds 1.7
    filtered26=((df['dog_percent']>0)&(df['fav_percent']<0.8)&(df['dog_rank']<=100)&(df['Fav_Odds']>=1.7)&(df['Fav_Odds']<=1.8)) #hard womens odds 1.7
    #filtered=df[filtered1|filtered2|filtered3|filtered4|filtered5|filtered6|filtered7|filtered8|filtered21|filtered22|filtered23|filtered24|filtered25|filtered26]
    #filtered=df[filtered26]
    
    #mens clay
    filtered1=((df['dog_percent']>0)&(df['fav_percent']<0.3)&(df['Fav_Odds']>=1.5)&(df['Fav_Odds']<=1.6)) #mens clay 54% odds 1.5, 1.7
    filtered2=((df['dog_percent']>0)&(df['fav_percent']<0.3)&(df['Fav_Odds']>=1.7)&(df['Fav_Odds']<=1.8)) #mens clay 54% odds 1.5, 1.7
    filtered3=((df['dog_percent']>0)&(df['fav_percent']<10)&(df['Dog_Top100']>0.6)&(df['Fav_Odds']>=1.7)&(df['Fav_Odds']<=1.8)) #mens clay 60% odds 1.7
    #filtered=df[filtered1|filtered2|filtered3]



    #womens hard
    filtered1=((df['dog_percent']>0.5)&(df['fav_percent']<1)&(df['Fav_Odds']>=1.7)&(df['Fav_Odds']<=1.8)) #womens clay 53% odds 1.7
    filtered2=((df['dog_percent']>0.5)&(df['fav_percent']<0.6)&(df['Fav_Odds']>=1.7)&(df['Fav_Odds']<=1.8)) #womens clay 59% odds 1.7
    filtered3=((df['dog_percent']>0.5)&(df['fav_percent']<5)&(df['Fav_Odds']>=1.7)&(df['Fav_Odds']<=1.8)) #womens clay 59% odds 1.7
    filtered5=((df['dog_percent']>0)&(df['fav_percent']<0.5)&(df['Dog_Games']>10)&(df['Fav_Games']>10)&(df['Fav_Odds']>=1.5)&(df['Fav_Odds']<=1.9)) #1.5 - 1.9
    filtered6=((df['dog_percent']>0.5)&(df['fav_percent']<5)&(df['Dog_Games']>10)&(df['Fav_Games']>10)&(df['Fav_Odds']>=1.6)&(df['Fav_Odds']<=1.9))
    filtered7=((df['Dog_Top100']>0.4)&(df['fav_percent']<5)&(df['Dog_Games']>10)&(df['Fav_Games']>10)&(df['Fav_Odds']>=1.6)&(df['Fav_Odds']<=1.9)) #1.6 - 1.9
    filtered8=((df['Fav_Top100']<0.5)&(df['fav_percent']<5)&(df['Dog_Games']>10)&(df['Fav_Games']>10)&(df['Fav_Odds']>=1.5)&(df['Fav_Odds']<=1.9)) #1.5 - 1.9
    filtered21=((df['dog_percent']>0.5)&(df['fav_percent']<1)&(df['dog_rank']<=100)&(df['Fav_Odds']>=1.6)&(df['Fav_Odds']<=1.8)) #hard womens odds 1.6,1.7
    filtered22=((df['dog_percent']>0)&(df['fav_percent']<1)&(df['dog_rank']<=100)&(df['Fav_Odds']>=1.7)&(df['Fav_Odds']<=1.8)) #hard womens odds 1.7
    filtered24=((df['dog_percent']>0.5)&(df['fav_percent']<5)&(df['dog_rank']<=100)&(df['Fav_Odds']>=1.6)&(df['Fav_Odds']<=1.8)) #hard womens odds 1.6, 1.7
    filtered25=((df['dog_percent']>0.5)&(df['fav_percent']<5)&(df['dog_rank']<=200)&(df['Fav_Odds']>=1.7)&(df['Fav_Odds']<=1.8)) #hard womens odds 1.7
    filtered26=((df['dog_percent']>0)&(df['fav_percent']<0.8)&(df['dog_rank']<=100)&(df['Fav_Odds']>=1.7)&(df['Fav_Odds']<=1.8)) #hard womens odds 1.7
    #filtered=df[filtered1|filtered2|filtered3|filtered5|filtered6|filtered7|filtered8|filtered21|filtered22|filtered24|filtered25|filtered26]
    #mens hard
    filtered1=((df['Fav_Top100']<df['Dog_Top100'])&(df['dog_percent']>0.5)&(df['Fav_Odds']>=1.8)&(df['Fav_Odds']<=1.9)) #1.8, 58%
    filtered2=((df['dog_percent']>0.5)&(df['fav_percent']<0.6)&(df['Dog_Games']>10)&(df['Fav_Odds']>=1.7)&(df['Fav_Odds']<=1.8)) #1.7,1.8 55%
    filtered3=((df['dog_percent']>0.5)&(df['fav_percent']<0.5)&(df['Dog_Games']>10)&(df['Fav_Odds']>=1.7)&(df['Fav_Odds']<=1.8)) #1.7, 60%
    filtered4=((df['dog_percent']>0)&(df['fav_percent']<0.4)&(df['Dog_Games']>10)&(df['Fav_Odds']>=1.7)&(df['Fav_Odds']<=1.8)) #1.7, 55%
    filtered5=((df['dog_percent']>0)&(df['fav_percent']<0.5)&(df['Dog_Games']>10)&(df['Fav_Games']>10)&(df['Fav_Odds']>=1.7)&(df['Fav_Odds']<=1.8)) #1.7, 55%
    filtered6=((df['dog_percent']>0.3)&(df['fav_percent']<0.5)&(df['Dog_Games']>10)&(df['Fav_Games']>10)&(df['Fav_Odds']>=1.7)&(df['Fav_Odds']<=1.8)) #1.7, 56%
    filtered11=((df['dog_percent']>0.5)&(df['fav_percent']<0.6)&(df['Fav_Odds']>=1.5)&(df['Fav_Odds']<=1.6)) #mens hard 1.5, 1.8
    filtered31=((df['dog_percent']>0.5)&(df['fav_percent']<0.5)&(df['Fav_Odds']>=1.5)&(df['Fav_Odds']<=1.6)) #mens hard 1.5, 1.7, 1.8
    filtered41=((df['dog_percent']>0.5)&(df['fav_percent']<0.5)&(df['Fav_Odds']>=1.7)&(df['Fav_Odds']<=1.8))
    filtered61=((df['dog_percent']>0.5)&(df['fav_percent']<10)&(df['Fav_Odds']>=1.8)&(df['Fav_Odds']<=1.9)) #mens hard 58% odds 1.8    
    filtered01=((df['dog_percent']>0.5)&(df['fav_percent']<0.6)&(df['Fav_Odds']>=1.5)&(df['Fav_Odds']<=1.6)) #mens hard 1.5, 1.8
    filtered03=((df['dog_percent']>0.5)&(df['fav_percent']<0.5)&(df['Fav_Odds']>=1.5)&(df['Fav_Odds']<=1.6)) #mens hard 1.5, 1.7, 1.8
    filtered04=((df['dog_percent']>0.5)&(df['fav_percent']<0.5)&(df['Fav_Odds']>=1.7)&(df['Fav_Odds']<=1.8))
    filtered06=((df['dog_percent']>0.5)&(df['fav_percent']<10)&(df['Fav_Odds']>=1.8)&(df['Fav_Odds']<=1.9)) #mens hard 58% odds 1.8
    #filtered=df[filtered1|filtered2|filtered3|filtered4|filtered5|filtered6|filtered11|filtered31|filtered41|filtered61|filtered01|filtered03|filtered04|filtered06]
    filtered=df[filtered06]
    print(surface, sex)
    if len(filtered)>0:
        print(len(filtered[filtered['Winner']==filtered['Dog']])/len(filtered),len(filtered))
    return filtered

for odds in np.arange(1.7, 1.7, 0.1):
    odds=odds.round(1)
    clay_data_women=hist_data('Clay','Womens',odds)
    clay_data_men=hist_data('Clay','Mens',odds)
    hard_data_women=hist_data('Hard','Womens',odds)
    hard_data_men=hist_data('Hard','Mens',odds) 
    print(odds)
    test_1(clay_data_women,'Hard','Mens')
clay_data_men=hist_data('Hard','Mens',1)
result=test_1(clay_data_men,'Hard','Mens').copy()
result['Profit'] = result.apply(lambda row: -50 if row['Fav_Win'] else (50 * row['Dog_Odds']) - 50, axis=1)
result['Profit'].sum()
#result.to_clipboard(index=False)
# Out:
# Hard Mens
# 0.5342465753424658 146
# 185.0

# %%
df=hist_data('Hard','Womens',1)
filtered1=((df['dog_percent']>0.5)&(df['fav_percent']<1)&(df['Fav_Odds']>=1.7)&(df['Fav_Odds']<=1.8)) #womens clay 53% odds 1.7
filtered2=((df['dog_percent']>0.5)&(df['fav_percent']<0.6)&(df['Fav_Odds']>=1.7)&(df['Fav_Odds']<=1.8)) #womens clay 59% odds 1.7
filtered3=((df['dog_percent']>0.5)&(df['fav_percent']<5)&(df['Fav_Odds']>=1.7)&(df['Fav_Odds']<=1.8)) #womens clay 59% odds 1.7
filtered4=((df['dog_percent']>0)&(df['fav_percent']<0.5)&(df['Fav_Top100']<0.5)&(df['Fav_Odds']>=1.5)&(df['Fav_Odds']<=1.6)) #hard 1.5 odds
filtered5=((df['dog_percent']>0)&(df['fav_percent']<0.5)&(df['Dog_Games']>10)&(df['Fav_Games']>10)&(df['Fav_Odds']>=1.5)&(df['Fav_Odds']<=1.9)) #1.5 - 1.9
filtered6=((df['dog_percent']>0.5)&(df['fav_percent']<5)&(df['Dog_Games']>10)&(df['Fav_Games']>10)&(df['Fav_Odds']>=1.6)&(df['Fav_Odds']<=1.9))
filtered7=((df['Dog_Top100']>0.4)&(df['fav_percent']<5)&(df['Dog_Games']>10)&(df['Fav_Games']>10)&(df['Fav_Odds']>=1.6)&(df['Fav_Odds']<=1.9)) #1.6 - 1.9
filtered8=((df['Fav_Top100']<0.5)&(df['fav_percent']<5)&(df['Dog_Games']>10)&(df['Fav_Games']>10)&(df['Fav_Odds']>=1.5)&(df['Fav_Odds']<=1.9)) #1.5 - 1.9
filtered21=((df['dog_percent']>0.5)&(df['fav_percent']<1)&(df['dog_rank']<=100)&(df['Fav_Odds']>=1.6)&(df['Fav_Odds']<=1.8)) #hard womens odds 1.6,1.7
filtered22=((df['dog_percent']>0)&(df['fav_percent']<1)&(df['dog_rank']<=100)&(df['Fav_Odds']>=1.7)&(df['Fav_Odds']<=1.8)) #hard womens odds 1.7
filtered23=((df['dog_percent']>0)&(df['fav_percent']<0.5)&(df['dog_rank']<=100)&(df['Fav_Odds']>=1.6)&(df['Fav_Odds']<=1.7)) #hard womens odds 1.6
#filtered24=((df['dog_percent']>0.5)&(df['fav_percent']<5)&(df['dog_rank']<=100)&(df['Fav_Odds']>=1.6)&(df['Fav_Odds']<=1.8)) #hard womens odds 1.6, 1.7
filtered25=((df['dog_percent']>0.5)&(df['fav_percent']<5)&(df['dog_rank']<=200)&(df['Fav_Odds']>=1.7)&(df['Fav_Odds']<=1.8)) #hard womens odds 1.7
filtered26=((df['dog_percent']>0)&(df['fav_percent']<0.8)&(df['dog_rank']<=100)&(df['Fav_Odds']>=1.7)&(df['Fav_Odds']<=1.8)) #hard womens odds 1.7
#filtered=df[filtered1|filtered2|filtered3|filtered4|filtered5|filtered6|filtered7|filtered8|filtered21|filtered22|filtered23|filtered25|filtered26]
x=filtered1,filtered2,filtered3,filtered4,filtered5,filtered6,filtered7,filtered8,filtered21,filtered22,filtered23,filtered25,filtered26
count=0
for i in x:
    count=count+1

    result=df[i].copy()
    result['Profit'] = result.apply(lambda row: -50 if row['Fav_Win'] else (50 * row['Dog_Odds']) - 50, axis=1)
    if  (len(result[result['Winner']==result['Dog']])/len(result))>0.54:
        if len(result) > 100:
            print("$"+str(round(result['Profit'].sum())),len(result),round(len(result[result['Winner']==result['Dog']])/len(result),2),count)
            #print(len(result[result['Winner']==result['Dog']])/len(result),len(result))

result=df[filtered5].copy()#|filtered3|filtered4|filtered5|filtered6|filtered7|filtered8|filtered21|filtered22|filtered23|filtered25|filtered26].copy()
result['Profit'] = result.apply(lambda row: -50 if row['Fav_Win'] else (50 * row['Dog_Odds']) - 50, axis=1)
print(round(result['Profit'].sum()),len(result))
# Out:
# $1070 107 0.56 9
# $923 130 0.55 10
# $973 129 0.56 13
# 1011 187

# %%
#Fav / Dog Win percentage + odds filter
import pandas as pd
from sqlalchemy import create_engine
import pandas as pd
import numpy as np
import datetime

#data=data[(data['Fav_Odds']>=1.3)&(data['Fav_Odds']<=1.4)]

odds_filter=1.7
devengine = create_engine("sqlite:///C:/Git/tennis_atp/database/bets_sqllite.db")
time_now = datetime.datetime.now()
def hist_data(surface, sex, odds_filter):
    data=pd.read_sql_query(f"Select distinct * from results_{surface}_1 where date > '2024-01-01' ",con=devengine)#.to_clipboard(index=False)
    time_now_formatted = time_now.strftime("%Y-%m-%d")
    data["Fav_Odds"] = data.Fav_Odds.astype(float)
    data["Dog_Odds"] = data.Dog_Odds.astype(float)
    data['Fav_Win'] = data['Winner']==data['Fav']
    #data=data[(data['Fav_Odds']>=odds_filter)&(data['Fav_Odds']<=odds_filter+0.1)]
    #data=data[(data['Fav_Odds']>=1.5)&(data['Fav_Odds']<=1.9)]
    #print(odds_filter+0.1)
    data=data[data['Sex']==sex]
    return data
    
def test_1(df,surface,sex):
    #filtered1=((df['dog_percent']>0.5)&(df['fav_percent']<0.6)&(df['Fav_Odds']>=1.5)&(df['Fav_Odds']<=1.6)) #mens hard 1.5, 1.8
    #Clay Mens
    filtered1=((df['dog_percent']>0.5)&(df['fav_percent']<1)&(df['dog_rank']<=100)&(df['Fav_Odds']>=1.6)&(df['Fav_Odds']<=1.8)) #hard womens odds 1.6,1.7
    filtered2=((df['dog_percent']>0)&(df['fav_percent']<1)&(df['dog_rank']<=100)&(df['Fav_Odds']>=1.7)&(df['Fav_Odds']<=1.8)) #hard womens odds 1.7
    filtered3=((df['dog_percent']>0)&(df['fav_percent']<0.5)&(df['dog_rank']<=100)&(df['Fav_Odds']>=1.6)&(df['Fav_Odds']<=1.7)) #hard womens odds 1.6
    filtered4=((df['dog_percent']>0.5)&(df['fav_percent']<5)&(df['dog_rank']<=100)&(df['Fav_Odds']>=1.6)&(df['Fav_Odds']<=1.8)) #hard womens odds 1.6, 1.7
    filtered5=((df['dog_percent']>0.5)&(df['fav_percent']<5)&(df['dog_rank']<=200)&(df['Fav_Odds']>=1.7)&(df['Fav_Odds']<=1.8)) #hard womens odds 1.7
    filtered6=((df['dog_percent']>0)&(df['fav_percent']<0.8)&(df['dog_rank']<=100)&(df['Fav_Odds']>=1.7)&(df['Fav_Odds']<=1.8)) #hard womens odds 1.7

    filtered=df[filtered1|filtered2|filtered3|filtered4|filtered5|filtered6]

    print(surface, sex)
    if len(filtered)>0:
        print(len(filtered[filtered['Winner']==filtered['Dog']])/len(filtered),len(filtered))
    return filtered


for odds in np.arange(1.5, 1.9, 0.1):
    odds=odds.round(1)
    clay_data_women=hist_data('Clay','Womens',odds)
    clay_data_men=hist_data('Clay','Mens',odds)
    hard_data_women=hist_data('Hard','Womens',odds)
    hard_data_men=hist_data('Hard','Mens',odds) 
    print(odds)
    test_1(hard_data_women,'Hard','Womens')
clay_data_men=hist_data('Hard','Womens',1.7)
result=test_1(clay_data_men,'Hard','Womens').copy()
result['Profit'] = result.apply(lambda row: -50 if row['Fav_Win'] else (50 * row['Dog_Odds']) - 50, axis=1)
result['Profit'].sum(),len(result)
#result.to_clipboard(index=False)
# Out:
# 1.5
# Hard Womens
# 0.5228215767634855 241
# 1.6
# Hard Womens
# 0.5228215767634855 241
# 1.7
# Hard Womens
# 0.5228215767634855 241
# 1.8
# Hard Womens
# 0.5228215767634855 241
# Hard Womens
# 0.5228215767634855 241
# (1273.5, 241)

# %%
clay_data_men
# Out:
#             Date Winner_Odds               Winner  Fav_Odds  Dog_Odds  \
# 12    2024-01-02        1.19  Marketa Vondrousova      1.19      4.67
# 13    2024-01-02        1.66         Petra Martic      1.66      2.21
# 14    2024-01-02        1.63   Brenda Fruhvirtova      1.63      2.27
# 15    2024-01-02        2.01     Varvara Gracheva      1.79      2.01
# 16    2024-01-02        1.07           Cori Gauff      1.07      8.86
# ...          ...         ...                  ...       ...       ...
# 6050  2024-10-31        1.69         Suzan Lamens      1.69      2.14
# 6052  2024-10-31        2.31            Sijia Wei      1.60      2.31
# 6053  2024-10-31        1.26          Sofia Kenin      1.26      3.81
# 6054  2024-10-31        1.94          Anna Bondar      1.84      1.94
# 6056  2024-10-31        1.23     Leylah Fernandez      1.23      4.10
#
#                       Fav              Elo_Fav  Fav_Games               Dog  \
# 12    Marketa Vondrousova  Marketa Vondrousova         12    Olga Danilovic
# 13           Petra Martic         Petra Martic         17   Rebeka Masarova
# 14     Brenda Fruhvirtova   Brenda Fruhvirtova          6     Anna Blinkova
# 15      Tereza Martincova     Varvara Gracheva         10  Varvara Gracheva
# 16             Cori Gauff           Cori Gauff         12        Claire Liu
# ...                   ...                  ...        ...               ...
# 6050         Suzan Lamens         Suzan Lamens         13    Cristina Bucsa
# 6052     Rebecca Sramkova     Rebecca Sramkova         11         Sijia Wei
# 6053          Sofia Kenin          Sofia Kenin         14   Jessika Ponchet
# 6054     Martina Trevisan     Martina Trevisan         33       Anna Bondar
# 6056     Leylah Fernandez     Leylah Fernandez         23  Kimberly Birrell
#
#       Dog_Games  ...     Sex  fav_rank dog_rank  Elo_Fav_Elo  Elo_Dog_Elo  \
# 12           10  ...  Womens       7.0    121.0  1701.346953  1451.094007
# 13           14  ...  Womens      41.0     65.0  1642.401121  1591.876239
# 14           11  ...  Womens     117.0     48.0  1538.907085  1519.284027
# 15           11  ...  Womens     156.0     42.0  1572.712455  1545.453094
# 16           11  ...  Womens       3.0     95.0  2011.257817  1572.480029
# ...         ...  ...     ...       ...      ...          ...          ...
# 6050         28  ...  Womens      91.0     71.0  1735.428615  1634.961971
# 6052         10  ...  Womens      53.0    132.0  1732.004276  1576.085676
# 6053         10  ...  Womens      88.0    106.0  1609.208779  1606.195129
# 6054         14  ...  Womens     136.0     97.0  1467.509233  1408.864209
# 6056         14  ...  Womens      32.0    115.0  1734.401510  1701.016658
#
#       Fav_Top100  Dog_Top100  fav_rank_high  dog_rank_high Fav_Win
# 12           0.5         0.2            6.0           93.0    True
# 13           0.4         0.5           14.0           62.0    True
# 14           0.0         0.4          109.0           34.0    True
# 15           0.4         0.5           40.0           40.0   False
# 16           0.8         0.2            3.0           52.0    True
# ...          ...         ...            ...            ...     ...
# 6050         0.5         0.4           88.0           56.0    True
# 6052         0.7         0.3           51.0          132.0   False
# 6053         0.4         0.3            4.0          104.0    True
# 6054         0.4         0.2           18.0           50.0   False
# 6056         0.5         0.3           13.0          100.0    True
#
# [1731 rows x 22 columns]
