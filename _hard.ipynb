# %%
import pandas as pd
from sqlalchemy import create_engine
import pandas as pd
import numpy as np
import datetime
devengine = create_engine("sqlite:///C:/Git/tennis_atp/database/bets_sqllite.db")
time_now = datetime.datetime.now()
time_now_formatted = time_now.strftime("%Y-%m-%d")
hard_today=pd.read_pickle('.\Hard_Today')
hard_today=hard_today[hard_today['Resulted']=='False']
hard_today=hard_today[hard_today['Sex']=='Womens']
#hard_today=hard_today[hard_today['fav_rank_high']>hard_today['dog_rank_high']]
hard_today[['Time','Fav_Top100','Dog_Top100','Fav','fav_rank','fav_rank_high','dog_rank','dog_rank_high','Fav_Odds','fav_percent','Fav_Serve%','Fav_Return%','fav_last_five_win_perc','Dog','Dog_Odds','dog_percent','Dog_Serve%','Dog_Return%','dog_last_five_win_perc']]
# Out:
# Empty DataFrame
# Columns: [Time, Fav_Top100, Dog_Top100, Fav, fav_rank, fav_rank_high, dog_rank, dog_rank_high, Fav_Odds, fav_percent, Fav_Serve%, Fav_Return%, fav_last_five_win_perc, Dog, Dog_Odds, dog_percent, Dog_Serve%, Dog_Return%, dog_last_five_win_perc]
# Index: []

# %%
import pandas as pd
from sqlalchemy import create_engine
import pandas as pd
import numpy as np
import datetime
devengine = create_engine("sqlite:///C:/Git/tennis_atp/database/bets_sqllite.db")
time_now = datetime.datetime.now()
time_now_formatted = time_now.strftime("%Y-%m-%d")
hard_today=pd.read_pickle('.\Hard_Today')
hard_today=hard_today[hard_today['Resulted']=='False']
hard_today=hard_today[hard_today['Sex']!='Womens']
#hard_today=hard_today[hard_today['fav_rank_high']>hard_today['dog_rank_high']]
hard_today[['Time','Fav_Top100','Dog_Top100','Fav','fav_rank','fav_rank_high','dog_rank','dog_rank_high','Fav_Odds','fav_percent','Fav_Serve%','Fav_Return%','fav_last_five_win_perc','Dog','Dog_Odds','dog_percent','Dog_Serve%','Dog_Return%','dog_last_five_win_perc']]
# Out:
#      Time  Fav_Top100  Dog_Top100                      Fav  fav_rank  \
# 11  19:10         0.4         0.1           Gabriel Diallo     133.0
# 12  19:10         0.0         0.5            Ryan Peniston     187.0
# 13  20:40         0.3         0.0           Adrian Andreev     251.0
# 14  20:50         0.0         0.5            Calvin Hemery     209.0
# 15  21:35         0.4         0.3     Christopher Oconnell      61.0
# 16  21:40         0.0         0.0              Mirza Basic     603.0
# 17  22:00         0.3         0.4       Jan Lennard Struff      27.0
# 18  22:00         0.5         0.5        Jeffrey John Wolf      59.0
# 19  22:10         0.3         1.0             Gijs Brouwer     171.0
# 20  22:20         0.3         0.0              Arthur Fery     291.0
# 21  23:05         0.5         0.6  Botic Van De Zandschulp      65.0
# 22  23:30         0.4         0.2              Andy Murray      40.0
# 23  23:30         0.5         0.2           Matteo Arnaldi      46.0
# ...

# %%
hard_today=pd.read_pickle('.\Hard_Today')
hard_today=hard_today[hard_today['Resulted']=='True']
hard_today=hard_today[((hard_today['fav_rank']<hard_today['dog_rank'])&(hard_today['fav_rank_high']<hard_today['dog_rank_high']))|
                      ((hard_today['fav_rank']>hard_today['dog_rank'])&(hard_today['fav_rank_high']>hard_today['dog_rank_high']))]
hard_today[['Time','Fav_Top100','Dog_Top100','Fav','fav_rank','fav_rank_high','dog_rank','dog_rank_high','Fav_Odds','fav_percent','Fav_Serve%','Fav_Return%','fav_last_five_win_perc','Dog','Dog_Odds','dog_percent','Dog_Serve%','Dog_Return%','dog_last_five_win_perc']]
# Out:
#      Time  Fav_Top100  Dog_Top100                Fav  fav_rank  fav_rank_high  \
# 1   00:40         0.5         0.4        Arthur Fils      38.0           38.0
# 2   00:55         0.0         0.0      Daniel Rincon     199.0          198.0
# 3   01:00         0.3         0.0        Arthur Fery     291.0          280.0
# 4   01:00         0.2         0.0    Dominik Koepfer      79.0           50.0
# 5   02:35         0.3         1.0       Gijs Brouwer     171.0          114.0
# 6   03:30         0.4         1.0  Mikhail Kukushkin     211.0           39.0
# 10  16:15         0.0         0.0       Marc Polmans     160.0          116.0
#
#     dog_rank  dog_rank_high  Fav_Odds  fav_percent  Fav_Serve%  Fav_Return%  \
# 1       30.0           25.0      1.76     0.526316        0.75         0.13
# 2      247.0          247.0      1.47     0.500000        0.00         0.00
# 3      178.0          154.0      1.59     0.857143        0.00         0.00
# ...
