# %%
import pandas as pd
from sqlalchemy import create_engine
import pandas as pd
import numpy as np
import datetime
Fav_Win_Percentage=pd.read_pickle('Fav_Win_Percentage')
devengine = create_engine("sqlite:///C:/Git/tennis_atp/database/bets_sqllite.db")
time_now = datetime.datetime.now()
time_now_formatted = time_now.strftime("%Y-%m-%d")
hard_today=pd.read_pickle('.\Hard_Today')
hard_today['fav_percent_adj'] = np.ceil(hard_today['fav_percent'] * 10) / 10
hard_today['dog_percent_adj'] = np.ceil(hard_today['dog_percent'] * 10) / 10
hard_today_win_percent=pd.merge(hard_today,Fav_Win_Percentage,left_on=['fav_percent_adj','dog_percent_adj'],right_on=['fav_percent_adj','dog_percent_adj'])
hard_today=hard_today[hard_today['Resulted']=='False']
hard_today=hard_today[hard_today['Sex']=='Womens']
#hard_today=hard_today[hard_today['fav_percent']>hard_today['dog_percent']]
#hard_today=hard_today[hard_today['fav_percent']<hard_today['dog_percent']]

hard_today[['Time','Fav_Top100','Dog_Top100','Fav','fav_rank','fav_rank_high','dog_rank','dog_rank_high','Fav_Odds','fav_percent','Fav_Serve%','Fav_Return%','fav_last_five_win_perc','Dog','Dog_Odds','dog_percent','Dog_Serve%','Dog_Return%','dog_last_five_win_perc']]
#hard_today[(hard_today['dog_percent']>0.5)&(hard_today['fav_percent']>0)]
# Out:
# Empty DataFrame
# Columns: [Time, Fav_Top100, Dog_Top100, Fav, fav_rank, fav_rank_high, dog_rank, dog_rank_high, Fav_Odds, fav_percent, Fav_Serve%, Fav_Return%, fav_last_five_win_perc, Dog, Dog_Odds, dog_percent, Dog_Serve%, Dog_Return%, dog_last_five_win_perc]
# Index: []

# %%
import pandas as pd
from sqlalchemy import create_engine
import pandas as pd
import numpy as np
import datetime
devengine = create_engine("sqlite:///C:/Git/tennis_atp/database/bets_sqllite.db")
time_now = datetime.datetime.now()
time_now_formatted = time_now.strftime("%Y-%m-%d")
hard_today=pd.read_pickle('.\Hard_Today')
hard_today=hard_today[hard_today['Resulted']=='False']
hard_today=hard_today[hard_today['Sex']!='Womens']
hard_today['fav_percent_adj'] = np.ceil(hard_today['fav_percent'] * 10) / 10
hard_today['dog_percent_adj'] = np.ceil(hard_today['dog_percent'] * 10) / 10
hard_today[['Time','Fav_Top100','Dog_Top100','Fav','fav_rank','fav_rank_high','dog_rank','dog_rank_high','Fav_Odds','fav_percent','Fav_Serve%','Fav_Return%','fav_last_five_win_perc','Dog','Dog_Odds','dog_percent','Dog_Serve%','Dog_Return%','dog_last_five_win_perc']]
# Out:
#      Time  Fav_Top100  Dog_Top100                   Fav  fav_rank  \
# 12  13:05         0.5         0.0           Taro Daniel      78.0
# 13  13:50         0.2         0.0  Nikoloz Basilashvili     311.0
# 14  14:00         0.0         0.3    Tristan Schoolkate     177.0
# 15  15:20         0.2         0.3                 Li Tu     184.0
# 16  22:00         0.7         0.6      Alexander Zverev       3.0
# 17  22:00         0.4         0.4       Roman Safiullin      59.0
#
#     fav_rank_high  dog_rank  dog_rank_high  Fav_Odds  fav_percent  Fav_Serve%  \
# 12           58.0     469.0          469.0      1.19     0.500000        0.74
# 13           16.0     407.0          143.0      1.28     0.500000        0.70
# 14          167.0     187.0          187.0      1.46     0.531250        0.00
# 15          181.0     223.0          135.0      1.44     0.380952        0.00
# 16            2.0      11.0            3.0      1.40     0.682540        0.83
# 17           36.0     313.0           14.0      1.44     1.000000        0.86
#
#     Fav_Return%  fav_last_five_win_perc                 Dog  Dog_Odds  \
# 12         0.21                     1.0      Kasidit Samrej      4.49
# 13         0.16                     0.4       Hiroki Moriya      3.49
# 14         0.00                     0.8         Omar Jasika      2.59
# 15         0.00                     0.6   Antoine Escoffier      2.65
# 16         0.26                     0.6  Stefanos Tsitsipas      2.93
# 17         0.19                     0.6      Aslan Karatsev      2.68
#
#     dog_percent  Dog_Serve%  Dog_Return%  dog_last_five_win_perc
# 12     0.000000         NaN          NaN                     0.4
# 13     0.300000        0.70         0.29                     0.6
# 14     0.363636        0.00         0.00                     0.6
# 15     0.375000        0.00         0.00                     0.4
# 16     0.459459        0.86         0.21                     0.8
# 17     0.428571        0.75         0.22                     0.8

# %%
hard_today_win_percent=hard_today_win_percent[hard_today_win_percent['Resulted']=='False']
hard_today_win_percent=hard_today_win_percent[hard_today_win_percent['Sex']!='Woxmens']
hard_today_win_percent[['Time','Fav_Win_Percentage','Fav','Fav_Odds','fav_percent','dog_percent','Dog','Dog_Odds']][hard_today_win_percent['Fav_Win_Percentage']>0.7].sort_values(by=['Fav_Win_Percentage'],ascending=False )
# Out:
# Empty DataFrame
# Columns: [Time, Fav_Win_Percentage, Fav, Fav_Odds, fav_percent, dog_percent, Dog, Dog_Odds]
# Index: []

# %%
import pandas as pd
from sqlalchemy import create_engine
import pandas as pd
import numpy as np
import datetime
Fav_Win_Percentage=pd.read_pickle('Fav_Win_Percentage')
devengine = create_engine("sqlite:///C:/Git/tennis_atp/database/bets_sqllite.db")
time_now = datetime.datetime.now()
time_now_formatted = time_now.strftime("%Y-%m-%d")
hard_today=pd.read_pickle('.\Hard_Today')
hard_today['fav_percent_adj'] = np.ceil(hard_today['fav_percent'] * 10) / 10
hard_today['dog_percent_adj'] = np.ceil(hard_today['dog_percent'] * 10) / 10
hard_today_win_percent=pd.merge(hard_today,Fav_Win_Percentage,left_on=['fav_percent_adj','dog_percent_adj'],right_on=['fav_percent_adj','dog_percent_adj'])
hard_today=hard_today[hard_today['Resulted']=='False']
hard_today=hard_today[hard_today['Sex']=='Womens']
#hard_today=hard_today[hard_today['fav_percent']>hard_today['dog_percent']]
#hard_today=hard_today[hard_today['fav_percent']<hard_today['dog_percent']]

hard_today[['Time','Fav_Top100','Dog_Top100','Fav','fav_rank','fav_rank_high','dog_rank','dog_rank_high','Fav_Odds','fav_percent','Fav_Serve%','Fav_Return%','fav_last_five_win_perc','Dog','Dog_Odds','dog_percent','Dog_Serve%','Dog_Return%','dog_last_five_win_perc']]
hard_today_win_percent=hard_today_win_percent[hard_today_win_percent['Resulted']=='False']
hard_today_win_percent=hard_today_win_percent[hard_today_win_percent['Sex']!='Woxmcens']
hard_today_win_percent[['Time','Fav_Win_Percentage','Fav','Fav_Odds','fav_percent','dog_percent','Dog','Dog_Odds']][hard_today_win_percent['Fav_Win_Percentage']>0.7].sort_values(by=['Time'],ascending=True )
# Out:
# Empty DataFrame
# Columns: [Time, Fav_Win_Percentage, Fav, Fav_Odds, fav_percent, dog_percent, Dog, Dog_Odds]
# Index: []

# %%
import pandas as pd
from sqlalchemy import create_engine
import pandas as pd
import numpy as np
import datetime
Fav_Win_Percentage=pd.read_pickle('Fav_Win_Percentage')
devengine = create_engine("sqlite:///C:/Git/tennis_atp/database/bets_sqllite.db")
time_now = datetime.datetime.now()
time_now_formatted = time_now.strftime("%Y-%m-%d")
hard_today=pd.read_pickle('.\Hard_Today')
hard_today['fav_percent_adj'] = np.ceil(hard_today['fav_percent'] * 10) / 10
hard_today['dog_percent_adj'] = np.ceil(hard_today['dog_percent'] * 10) / 10
hard_today_win_percent=pd.merge(hard_today,Fav_Win_Percentage,left_on=['fav_percent_adj','dog_percent_adj'],right_on=['fav_percent_adj','dog_percent_adj'])
hard_today=hard_today[hard_today['Resulted']=='False']
hard_today=hard_today[hard_today['Sex']=='Womens']
#hard_today=hard_today[hard_today['fav_percent']>hard_today['dog_percent']]
#hard_today=hard_today[hard_today['fav_percent']<hard_today['dog_percent']]

hard_today[['Time','Fav_Top100','Dog_Top100','Fav','fav_rank','fav_rank_high','dog_rank','dog_rank_high','Fav_Odds','fav_percent','Fav_Serve%','Fav_Return%','fav_last_five_win_perc','Dog','Dog_Odds','dog_percent','Dog_Serve%','Dog_Return%','dog_last_five_win_perc']]
#hard_today_win_percent=hard_today_win_percent[hard_today_win_percent['Resulted']!='False']
hard_today_win_percent=hard_today_win_percent[hard_today_win_percent['Sex']!='Woxmcens']
hard_today_win_percent=hard_today_win_percent[hard_today_win_percent['Fav_Odds']>1.8]
hard_today_win_percent[['Time','Fav_Win_Percentage','Fav','Fav_Odds','fav_percent','dog_percent','Dog','Dog_Odds']][hard_today_win_percent['Fav_Win_Percentage']<0.9].sort_values(by=['Time'],ascending=True )#.to_clipboard(index=False)
#pd.read_pickle('.\Hard_Today')
# Out:
# Empty DataFrame
# Columns: [Time, Fav_Win_Percentage, Fav, Fav_Odds, fav_percent, dog_percent, Dog, Dog_Odds]
# Index: []

# %%
import pandas as pd
from sqlalchemy import create_engine
import pandas as pd
import numpy as np
import datetime
Fav_Win_Percentage=pd.read_pickle('Fav_Win_Percentage')
devengine = create_engine("sqlite:///C:/Git/tennis_atp/database/bets_sqllite.db")
time_now = datetime.datetime.now()
time_now_formatted = time_now.strftime("%Y-%m-%d")
hard_today=pd.read_pickle('.\Hard_Today')
hard_today['fav_percent_adj'] = np.ceil(hard_today['fav_percent'] * 10) / 10
hard_today['dog_percent_adj'] = np.ceil(hard_today['dog_percent'] * 10) / 10
hard_today_win_percent=pd.merge(hard_today,Fav_Win_Percentage,left_on=['fav_percent_adj','dog_percent_adj'],right_on=['fav_percent_adj','dog_percent_adj'])
hard_today=hard_today[hard_today['Resulted']=='False']
hard_today=hard_today[hard_today['Sex']=='Womens']
#hard_today=hard_today[hard_today['fav_percent']>hard_today['dog_percent']]
#hard_today=hard_today[hard_today['fav_percent']<hard_today['dog_percent']]

hard_today[['Time','Fav_Top100','Dog_Top100','Fav','fav_rank','fav_rank_high','dog_rank','dog_rank_high','Fav_Odds','fav_percent','Fav_Serve%','Fav_Return%','fav_last_five_win_perc','Dog','Dog_Odds','dog_percent','Dog_Serve%','Dog_Return%','dog_last_five_win_perc']]
hard_today_win_percent=hard_today_win_percent[hard_today_win_percent['Resulted']=='False']
hard_today_win_percent=hard_today_win_percent[hard_today_win_percent['Sex']!='Woxmcens']
hard_today_win_percent=hard_today_win_percent[['Time','Fav_Win_Percentage','Fav','Fav_Odds','fav_percent','dog_percent','Dog','Dog_Odds']][hard_today_win_percent['Fav_Odds']<1.3].sort_values(by=['Time'],ascending=True )
#hard_today_win_percent[hard_today_win_percent['Fav_Win_Percentage']<0.6].to_clipboard(index=False)
hard_today_win_percent
# Out:
#      Time  Fav_Win_Percentage                   Fav  Fav_Odds  fav_percent  \
# 10  13:05            0.333333           Taro Daniel      1.19          0.5
# 11  13:50            0.285714  Nikoloz Basilashvili      1.28          0.5
#
#     dog_percent             Dog  Dog_Odds
# 10          0.0  Kasidit Samrej      4.49
# 11          0.3   Hiroki Moriya      3.49

# %%
import pandas as pd
from sqlalchemy import create_engine
import pandas as pd
import numpy as np
import datetime
Fav_Win_Percentage=pd.read_pickle('Fav_Win_Percentage')
devengine = create_engine("sqlite:///C:/Git/tennis_atp/database/bets_sqllite.db")
time_now = datetime.datetime.now()
time_now_formatted = time_now.strftime("%Y-%m-%d")
hard_today=pd.read_pickle('.\Hard_Today')
hard_today['fav_percent_adj'] = np.ceil(hard_today['fav_percent'] * 10) / 10
hard_today['dog_percent_adj'] = np.ceil(hard_today['dog_percent'] * 10) / 10
hard_today_win_percent=pd.merge(hard_today,Fav_Win_Percentage,left_on=['fav_percent_adj','dog_percent_adj'],right_on=['fav_percent_adj','dog_percent_adj'])
hard_today_win_percent=hard_today_win_percent[hard_today_win_percent['Resulted']!='Falxse']
hard_today_win_percent=hard_today_win_percent[hard_today_win_percent['Sex']!='Woxmcens']
hard_today_win_percent[['Time','Fav_Win_Percentage','Fav','Fav_Odds','fav_percent','dog_percent','Dog','Dog_Odds']].sort_values(by=['Time'],ascending=True )#.to_clipboard(index=False)
# Out:
#      Time  Fav_Win_Percentage                        Fav  Fav_Odds  \
# 0   00:10            0.450000           Maks Kasnikowski      1.74
# 1   00:40            0.461538           Alexander Zverev      1.47
# 3   00:40            0.523810              Kei Nishikori      1.53
# 4   01:25            0.428571                Jack Draper      1.66
# 5   03:30            0.636364             Carlos Alcaraz      1.18
# 6   03:50            0.777778                Holger Rune      1.32
# 8   06:05            0.562500            Grigor Dimitrov      1.21
# 7   10:05            0.777778               Yuta Shimizu      1.22
# 9   11:05            0.800000  Nicolas Moreno De Alboran      1.56
# 10  13:05            0.333333                Taro Daniel      1.19
# 11  13:50            0.285714       Nikoloz Basilashvili      1.28
# 12  14:00            0.600000         Tristan Schoolkate      1.46
# 13  15:20            0.647059                      Li Tu      1.44
# 2   22:00            0.461538           Alexander Zverev      1.40
#
#     fav_percent  dog_percent                 Dog  Dog_Odds
# 0      0.611111     0.400000         Ethan Quinn      2.01
# 1      0.681159     0.500000         Arthur Fils      2.68
# 3      0.333333     0.680000         Lukas Klein      2.41
# 4      0.687500     0.640000      Alex De Minaur      2.22
# 5      0.750000     0.540541         Ugo Humbert      4.93
# 6      0.743590     0.500000       Arthur Cazaux      3.41
# 8      0.745455     0.307692  Arthur Rinderknech      4.40
# 7      0.750000     0.500000           Ajeet Rai      4.04
# 9      0.625000     0.300000      Jurij Rodionov      2.34
# 10     0.500000     0.000000      Kasidit Samrej      4.49
# 11     0.500000     0.300000       Hiroki Moriya      3.49
# 12     0.531250     0.363636         Omar Jasika      2.59
# 13     0.380952     0.375000   Antoine Escoffier      2.65
# 2      0.682540     0.459459  Stefanos Tsitsipas      2.93
