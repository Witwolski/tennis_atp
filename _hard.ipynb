# %%
import pandas as pd
from sqlalchemy import create_engine
import pandas as pd
import numpy as np
import datetime
Fav_Win_Percentage=pd.read_pickle('Fav_Win_Percentage')
devengine = create_engine("sqlite:///C:/Git/tennis_atp/database/bets_sqllite.db")
time_now = datetime.datetime.now()
time_now_formatted = time_now.strftime("%Y-%m-%d")
hard_today=pd.read_pickle('.\Hard_Today')
hard_today['fav_percent_adj'] = np.ceil(hard_today['fav_percent'] * 10) / 10
hard_today['dog_percent_adj'] = np.ceil(hard_today['dog_percent'] * 10) / 10
hard_today_win_percent=pd.merge(hard_today,Fav_Win_Percentage,left_on=['fav_percent_adj','dog_percent_adj'],right_on=['fav_percent_adj','dog_percent_adj'])
hard_today=hard_today[hard_today['Resulted']=='False']
hard_today=hard_today[hard_today['Sex']=='Womens']
#hard_today=hard_today[hard_today['fav_percent']>hard_today['dog_percent']]
#hard_today=hard_today[hard_today['fav_percent']<hard_today['dog_percent']]

hard_today[['Time','Fav_Top100','Dog_Top100','Fav','fav_rank','fav_rank_high','dog_rank','dog_rank_high','Fav_Odds','fav_percent','Fav_Serve%','Fav_Return%','fav_last_five_win_perc','Dog','Dog_Odds','dog_percent','Dog_Serve%','Dog_Return%','dog_last_five_win_perc']]
# Out:
#      Time  Fav_Top100  Dog_Top100                     Fav  fav_rank  \
# 0   01:00         0.3         0.2             Mai Hontama     120.0
# 1   01:00         0.4         0.0   Aliaksandra Sasnovich      97.0
# 2   01:00         0.4         0.5         Nadia Podoroska      84.0
# 3   01:00         0.5         0.4       Mccartney Kessler     123.0
# 4   01:00         0.5         0.6          Heather Watson     147.0
# 5   01:05         0.3         0.3         Maria Timofeeva     102.0
# 6   02:30         0.3         0.4             Anna Bondar     112.0
# 7   02:30         0.4         0.1         Taylor Townsend      77.0
# 8   02:30         0.5         0.6         Rebeka Masarova      96.0
# 9   02:30         1.0         0.3  Jessica Bouzas Maneiro     125.0
# 10  02:30         0.0         0.4       Darja Semenistaja     110.0
# 11  02:30         0.0         0.3               Kayla Day      88.0
# 12  02:30         0.5         0.2            Clara Tauson      93.0
# 13  04:00         0.8         0.6             Iga Swiatek       1.0
# 14  04:00         0.4         0.1              Nao Hibino      80.0
# 15  04:00         0.3         0.2              Claire Liu     111.0
# 16  04:00         0.5         0.2         Laura Siegemund      87.0
# 17  04:00         0.3         0.0             Sara Errani     100.0
# 18  04:00         0.5         0.3          Katie Volynets     131.0
# 19  05:30         0.3         0.3            Storm Hunter     124.0
# 20  05:30         0.3         0.3            Alycia Parks     119.0
#
#     fav_rank_high  dog_rank  dog_rank_high  Fav_Odds  fav_percent  Fav_Serve%  \
# 0           116.0      76.0           71.0      1.51     0.416667        0.49
# 1            29.0     630.0           39.0      1.16     1.000000        0.67
# 2            36.0     118.0          115.0      1.73     0.500000        0.67
# 3           120.0      91.0           33.0      1.83     0.571429         NaN
# 4            38.0      85.0           46.0      1.76     0.307692        0.65
# 5           100.0     107.0          105.0      1.77     0.666667        0.00
# 6            50.0      69.0           26.0      1.78     0.250000        0.70
# 7            61.0     115.0          100.0      1.13     0.428571        0.64
# 8            62.0     127.0          111.0      1.49     0.636364        0.54
# 9           124.0      92.0           82.0      1.60     0.500000        0.00
# 10          110.0     104.0           97.0      1.79     0.250000        0.00
# 11           86.0     121.0          109.0      1.60     0.181818        0.67
# 12           33.0     117.0           22.0      1.18     0.416667        0.68
# 13            1.0       9.0            3.0      1.16     0.808511        0.76
# 14           56.0     113.0           61.0      1.71     0.700000        0.61
# 15           52.0      95.0           65.0      1.62     0.562500        0.63
# 16           27.0     199.0          143.0      1.63     0.500000        0.63
# 17            5.0     176.0          176.0      1.76     0.333333        0.50
# 18           74.0     101.0           97.0      1.28     0.466667        0.46
# 19          119.0     103.0           11.0      1.35     0.714286        0.57
# 20           40.0      89.0           12.0      1.83     0.428571        0.73
#
#     Fav_Return%  fav_last_five_win_perc                        Dog  Dog_Odds  \
# 0          0.33                     0.4           Tamara Korpatsch      2.50
# 1          0.38                     0.2           Alexandra Krunic      5.07
# 2          0.30                     0.6                Julia Riera      2.07
# 3           NaN                     0.8              Camila Osorio      1.94
# 4          0.32                     0.4               Oceane Dodin      2.02
# 5          0.00                     0.2      Marina Bassols Ribera      2.04
# 6          0.30                     0.2  Anna Karolina Schmiedlova      2.00
# 7          0.29                     0.4              Laura Pigossi      5.76
# 8          0.26                     0.6           Rebecca Sramkova      2.56
# 9          0.00                     0.4               Emina Bektas      2.30
# 10         0.00                     0.4            Arina Rodionova      1.98
# 11         0.18                     0.2            Emiliana Arango      2.29
# 12         0.29                     0.4            Tamara Zidansek      4.71
# 13         0.50                     0.8              Maria Sakkari      5.37
# 14         0.40                     0.6              Jule Niemeier      2.10
# 15         0.37                     0.6          Kamilla Rakhimova      2.24
# 16         0.28                     0.2           Robin Montgomery      2.22
# 17         0.40                     0.6             Alexandra Eala      2.02
# 18         0.44                     0.4             Renata Zarazua      3.58
# 19         0.15                     0.4               Alize Cornet      3.10
# 20         0.24                     0.0           Yanina Wickmayer      1.93
#
#     dog_percent  Dog_Serve%  Dog_Return%  dog_last_five_win_perc
# 0      0.444444        0.58         0.27                     0.2
# 1      0.000000         NaN          NaN                     0.0
# 2      0.333333        0.00         0.00                     0.4
# 3      0.500000        0.57         0.37                     0.4
# 4      0.333333        0.60         0.32                     0.6
# 5      0.388889        0.61         0.22                     0.6
# 6      0.550000        0.51         0.34                     0.4
# 7      0.125000        0.58         0.33                     0.0
# 8      0.666667        0.00         0.00                     0.6
# 9      0.538462        0.58         0.10                     0.2
# 10     0.285714        0.50         0.11                     0.2
# 11     0.222222        0.00         0.00                     0.2
# 12     0.285714        0.60         0.33                     0.0
# 13     0.526316        0.75         0.33                     1.0
# 14     0.300000        0.69         0.35                     0.6
# 15     0.285714        0.60         0.33                     0.2
# 16     0.454545        0.65         0.18                     0.6
# 17     0.000000        0.12         0.29                     0.2
# 18     0.333333        0.52         0.21                     0.2
# 19     0.500000         NaN          NaN                     0.2
# 20     0.333333        0.62         0.39                     0.0

# %%
import pandas as pd
from sqlalchemy import create_engine
import pandas as pd
import numpy as np
import datetime
devengine = create_engine("sqlite:///C:/Git/tennis_atp/database/bets_sqllite.db")
time_now = datetime.datetime.now()
time_now_formatted = time_now.strftime("%Y-%m-%d")
hard_today=pd.read_pickle('.\Hard_Today')
hard_today=hard_today[hard_today['Resulted']=='False']
hard_today=hard_today[hard_today['Sex']!='Womens']
hard_today['fav_percent_adj'] = np.ceil(hard_today['fav_percent'] * 10) / 10
hard_today['dog_percent_adj'] = np.ceil(hard_today['dog_percent'] * 10) / 10
hard_today[['Time','Fav_Top100','Dog_Top100','Fav','fav_rank','fav_rank_high','dog_rank','dog_rank_high','Fav_Odds','fav_percent','Fav_Serve%','Fav_Return%','fav_last_five_win_perc','Dog','Dog_Odds','dog_percent','Dog_Serve%','Dog_Return%','dog_last_five_win_perc']]
# Out:
#      Time  Fav_Top100  Dog_Top100                Fav  fav_rank  fav_rank_high  \
# 21  07:00         0.7         0.5  Matteo Berrettini     154.0            6.0
# 22  07:00         0.8         0.8     Carlos Alcaraz       2.0            1.0
#
#     dog_rank  dog_rank_high  Fav_Odds  fav_percent  Fav_Serve%  Fav_Return%  \
# 21      60.0           46.0      1.73     0.571429        0.88         0.18
# 22       4.0            1.0      1.40     0.705882        0.84         0.31
#
#     fav_last_five_win_perc              Dog  Dog_Odds  dog_percent  \
# 21                     0.8      Nuno Borges      2.03     0.615385
# 22                     0.8  Daniil Medvedev      2.99     0.740741
#
#     Dog_Serve%  Dog_Return%  dog_last_five_win_perc
# 21        0.84         0.13                     0.6
# 22        0.86         0.27                     0.8

# %%
hard_today_win_percent=hard_today_win_percent[hard_today_win_percent['Resulted']=='False']
hard_today_win_percent=hard_today_win_percent[hard_today_win_percent['Sex']!='Woxmens']
hard_today_win_percent[['Time','Fav_Win_Percentage','Fav','Fav_Odds','fav_percent','dog_percent','Dog','Dog_Odds']][hard_today_win_percent['Fav_Win_Percentage']>0.7].sort_values(by=['Fav_Win_Percentage'],ascending=False )
# Out:
#      Time  Fav_Win_Percentage          Fav  Fav_Odds  fav_percent  \
# 15  04:00            0.714286  Iga Swiatek      1.16     0.808511
#
#     dog_percent            Dog  Dog_Odds
# 15     0.526316  Maria Sakkari      5.37

# %%
import pandas as pd
from sqlalchemy import create_engine
import pandas as pd
import numpy as np
import datetime
Fav_Win_Percentage=pd.read_pickle('Fav_Win_Percentage')
devengine = create_engine("sqlite:///C:/Git/tennis_atp/database/bets_sqllite.db")
time_now = datetime.datetime.now()
time_now_formatted = time_now.strftime("%Y-%m-%d")
hard_today=pd.read_pickle('.\Hard_Today')
hard_today['fav_percent_adj'] = np.ceil(hard_today['fav_percent'] * 10) / 10
hard_today['dog_percent_adj'] = np.ceil(hard_today['dog_percent'] * 10) / 10
hard_today_win_percent=pd.merge(hard_today,Fav_Win_Percentage,left_on=['fav_percent_adj','dog_percent_adj'],right_on=['fav_percent_adj','dog_percent_adj'])
hard_today=hard_today[hard_today['Resulted']=='False']
hard_today=hard_today[hard_today['Sex']=='Womens']
#hard_today=hard_today[hard_today['fav_percent']>hard_today['dog_percent']]
#hard_today=hard_today[hard_today['fav_percent']<hard_today['dog_percent']]

hard_today[['Time','Fav_Top100','Dog_Top100','Fav','fav_rank','fav_rank_high','dog_rank','dog_rank_high','Fav_Odds','fav_percent','Fav_Serve%','Fav_Return%','fav_last_five_win_perc','Dog','Dog_Odds','dog_percent','Dog_Serve%','Dog_Return%','dog_last_five_win_perc']]
hard_today_win_percent=hard_today_win_percent[hard_today_win_percent['Resulted']=='False']
hard_today_win_percent=hard_today_win_percent[hard_today_win_percent['Sex']!='Woxmcens']
hard_today_win_percent[['Time','Fav_Win_Percentage','Fav','Fav_Odds','fav_percent','dog_percent','Dog','Dog_Odds']][hard_today_win_percent['Fav_Win_Percentage']>0.7].sort_values(by=['Time'],ascending=True )
# Out:
#      Time  Fav_Win_Percentage          Fav  Fav_Odds  fav_percent  \
# 15  04:00            0.714286  Iga Swiatek      1.16     0.808511
#
#     dog_percent            Dog  Dog_Odds
# 15     0.526316  Maria Sakkari      5.37

# %%
import pandas as pd
from sqlalchemy import create_engine
import pandas as pd
import numpy as np
import datetime
Fav_Win_Percentage=pd.read_pickle('Fav_Win_Percentage')
devengine = create_engine("sqlite:///C:/Git/tennis_atp/database/bets_sqllite.db")
time_now = datetime.datetime.now()
time_now_formatted = time_now.strftime("%Y-%m-%d")
hard_today=pd.read_pickle('.\Hard_Today')
hard_today['fav_percent_adj'] = np.ceil(hard_today['fav_percent'] * 10) / 10
hard_today['dog_percent_adj'] = np.ceil(hard_today['dog_percent'] * 10) / 10
hard_today_win_percent=pd.merge(hard_today,Fav_Win_Percentage,left_on=['fav_percent_adj','dog_percent_adj'],right_on=['fav_percent_adj','dog_percent_adj'])
hard_today=hard_today[hard_today['Resulted']=='False']
hard_today=hard_today[hard_today['Sex']=='Womens']
#hard_today=hard_today[hard_today['fav_percent']>hard_today['dog_percent']]
#hard_today=hard_today[hard_today['fav_percent']<hard_today['dog_percent']]

hard_today[['Time','Fav_Top100','Dog_Top100','Fav','fav_rank','fav_rank_high','dog_rank','dog_rank_high','Fav_Odds','fav_percent','Fav_Serve%','Fav_Return%','fav_last_five_win_perc','Dog','Dog_Odds','dog_percent','Dog_Serve%','Dog_Return%','dog_last_five_win_perc']]
#hard_today_win_percent=hard_today_win_percent[hard_today_win_percent['Resulted']!='False']
hard_today_win_percent=hard_today_win_percent[hard_today_win_percent['Sex']!='Woxmcens']
hard_today_win_percent=hard_today_win_percent[hard_today_win_percent['Fav_Odds']>1.8]
hard_today_win_percent[['Time','Fav_Win_Percentage','Fav','Fav_Odds','fav_percent','dog_percent','Dog','Dog_Odds']][hard_today_win_percent['Fav_Win_Percentage']<0.9].sort_values(by=['Time'],ascending=True )#.to_clipboard(index=False)
#pd.read_pickle('.\Hard_Today')
# Out:
#     Time  Fav_Win_Percentage                Fav  Fav_Odds  fav_percent  \
# 5  01:00            0.525000  Mccartney Kessler      1.83     0.571429
# 4  05:30            0.655738       Alycia Parks      1.83     0.428571
#
#    dog_percent               Dog  Dog_Odds
# 5     0.500000     Camila Osorio      1.94
# 4     0.333333  Yanina Wickmayer      1.93

# %%
import pandas as pd
from sqlalchemy import create_engine
import pandas as pd
import numpy as np
import datetime
Fav_Win_Percentage=pd.read_pickle('Fav_Win_Percentage')
devengine = create_engine("sqlite:///C:/Git/tennis_atp/database/bets_sqllite.db")
time_now = datetime.datetime.now()
time_now_formatted = time_now.strftime("%Y-%m-%d")
hard_today=pd.read_pickle('.\Hard_Today')
hard_today['fav_percent_adj'] = np.ceil(hard_today['fav_percent'] * 10) / 10
hard_today['dog_percent_adj'] = np.ceil(hard_today['dog_percent'] * 10) / 10
hard_today_win_percent=pd.merge(hard_today,Fav_Win_Percentage,left_on=['fav_percent_adj','dog_percent_adj'],right_on=['fav_percent_adj','dog_percent_adj'])
hard_today=hard_today[hard_today['Resulted']=='False']
hard_today=hard_today[hard_today['Sex']=='Womens']
#hard_today=hard_today[hard_today['fav_percent']>hard_today['dog_percent']]
#hard_today=hard_today[hard_today['fav_percent']<hard_today['dog_percent']]

hard_today[['Time','Fav_Top100','Dog_Top100','Fav','fav_rank','fav_rank_high','dog_rank','dog_rank_high','Fav_Odds','fav_percent','Fav_Serve%','Fav_Return%','fav_last_five_win_perc','Dog','Dog_Odds','dog_percent','Dog_Serve%','Dog_Return%','dog_last_five_win_perc']]
hard_today_win_percent=hard_today_win_percent[hard_today_win_percent['Resulted']=='False']
hard_today_win_percent=hard_today_win_percent[hard_today_win_percent['Sex']!='Woxmcens']
hard_today_win_percent=hard_today_win_percent[['Time','Fav_Win_Percentage','Fav','Fav_Odds','fav_percent','dog_percent','Dog','Dog_Odds']][hard_today_win_percent['Fav_Odds']<1.3].sort_values(by=['Time'],ascending=True )
#hard_today_win_percent[hard_today_win_percent['Fav_Win_Percentage']<0.6].to_clipboard(index=False)
hard_today_win_percent
# Out:
#      Time  Fav_Win_Percentage                    Fav  Fav_Odds  fav_percent  \
# 2   01:00            1.000000  Aliaksandra Sasnovich      1.16     1.000000
# 9   02:30            0.700000        Taylor Townsend      1.13     0.428571
# 14  02:30            0.875000           Clara Tauson      1.18     0.416667
# 4   04:00            0.766667         Katie Volynets      1.28     0.466667
# 15  04:00            0.833333            Iga Swiatek      1.16     0.808511
#
#     dog_percent               Dog  Dog_Odds
# 2      0.000000  Alexandra Krunic      5.07
# 9      0.125000     Laura Pigossi      5.76
# 14     0.285714   Tamara Zidansek      4.71
# 4      0.333333    Renata Zarazua      3.58
# 15     0.526316     Maria Sakkari      5.37

# %%
import pandas as pd
from sqlalchemy import create_engine
import pandas as pd
import numpy as np
import datetime
Fav_Win_Percentage=pd.read_pickle('Fav_Win_Percentage')
devengine = create_engine("sqlite:///C:/Git/tennis_atp/database/bets_sqllite.db")
time_now = datetime.datetime.now()
time_now_formatted = time_now.strftime("%Y-%m-%d")
hard_today=pd.read_pickle('.\Hard_Today')
hard_today['fav_percent_adj'] = np.ceil(hard_today['fav_percent'] * 10) / 10
hard_today['dog_percent_adj'] = np.ceil(hard_today['dog_percent'] * 10) / 10
hard_today_win_percent=pd.merge(hard_today,Fav_Win_Percentage,left_on=['fav_percent_adj','dog_percent_adj'],right_on=['fav_percent_adj','dog_percent_adj'])
hard_today_win_percent=hard_today_win_percent[hard_today_win_percent['Resulted']!='Falxse']
hard_today_win_percent=hard_today_win_percent[hard_today_win_percent['Sex']!='Woxmcens']
hard_today_win_percent[['Time','Fav_Win_Percentage','Fav','Fav_Odds','fav_percent','dog_percent','Dog','Dog_Odds']].sort_values(by=['Time'],ascending=True )#.to_clipboard(index=False)
# Out:
#      Time  Fav_Win_Percentage                     Fav  Fav_Odds  fav_percent  \
# 0   01:00            0.440476             Mai Hontama      1.51     0.416667
# 2   01:00            0.655738         Nadia Podoroska      1.73     0.500000
# 5   01:00            0.525000       Mccartney Kessler      1.83     0.571429
# 6   01:00            0.500000          Heather Watson      1.76     0.307692
# 7   01:05            0.413793         Maria Timofeeva      1.77     0.666667
# 14  02:30            0.378378            Clara Tauson      1.18     0.416667
# 13  02:30            0.500000               Kayla Day      1.60     0.181818
# 12  02:30            0.625000       Darja Semenistaja      1.79     0.250000
# 11  02:30            0.392405  Jessica Bouzas Maneiro      1.60     0.500000
# 10  02:30            0.410256         Rebeka Masarova      1.49     0.636364
# 8   02:30            0.480000             Anna Bondar      1.78     0.250000
# 9   02:30            0.500000         Taylor Townsend      1.13     0.428571
# 3   04:00            0.655738          Katie Volynets      1.28     0.466667
# 1   04:00            0.440476         Laura Siegemund      1.63     0.500000
# 15  04:00            0.714286             Iga Swiatek      1.16     0.808511
# 16  04:00            0.368421              Nao Hibino      1.71     0.700000
# 17  04:00            0.555556              Claire Liu      1.62     0.562500
# 4   05:30            0.655738            Alycia Parks      1.83     0.428571
# 18  05:30            0.450000            Storm Hunter      1.35     0.714286
# 19  07:00            0.488372       Matteo Berrettini      1.73     0.571429
# 20  07:00            0.555556          Carlos Alcaraz      1.40     0.705882
#
#     dog_percent                        Dog  Dog_Odds
# 0      0.444444           Tamara Korpatsch      2.50
# 2      0.333333                Julia Riera      2.07
# 5      0.500000              Camila Osorio      1.94
# 6      0.333333               Oceane Dodin      2.02
# 7      0.388889      Marina Bassols Ribera      2.04
# 14     0.285714            Tamara Zidansek      4.71
# 13     0.222222            Emiliana Arango      2.29
# 12     0.285714            Arina Rodionova      1.98
# 11     0.538462               Emina Bektas      2.30
# 10     0.666667           Rebecca Sramkova      2.56
# 8      0.550000  Anna Karolina Schmiedlova      2.00
# 9      0.125000              Laura Pigossi      5.76
# 3      0.333333             Renata Zarazua      3.58
# 1      0.454545           Robin Montgomery      2.22
# 15     0.526316              Maria Sakkari      5.37
# 16     0.300000              Jule Niemeier      2.10
# 17     0.285714          Kamilla Rakhimova      2.24
# 4      0.333333           Yanina Wickmayer      1.93
# 18     0.500000               Alize Cornet      3.10
# 19     0.615385                Nuno Borges      2.03
# 20     0.740741            Daniil Medvedev      2.99
