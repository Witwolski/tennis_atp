# %%
import pandas as pd
from sqlalchemy import create_engine
import pandas as pd
import numpy as np
import datetime
devengine = create_engine("sqlite:///C:/Git/tennis_atp/database/bets_sqllite.db")
time_now = datetime.datetime.now()
time_now_formatted = time_now.strftime("%Y-%m-%d")
hard_today=pd.read_pickle('.\Hard_Today')
hard_today=hard_today[hard_today['Resulted']=='False']
hard_today[['Time','Fav_Top100','Dog_Top100','Fav','fav_rank','dog_rank','Fav_Odds','fav_percent','Fav_Serve%','Fav_Return%','fav_last_five_win_perc','Dog','Dog_Odds','dog_percent','Dog_Serve%','Dog_Return%','dog_last_five_win_perc']]
# Out:
#     Time  Fav_Top100  Dog_Top100                Fav  fav_rank  dog_rank  \
# 5  17:30         0.3         0.3    Moyuka Uchijima     174.0     127.0
# 6  17:30         0.2         0.0  Elizabeth Mandlik     167.0     195.0
# 7  17:30         0.1         0.5       Harriet Dart     161.0     171.0
# 8  19:30         0.3         0.0    Mathias Bourgue     272.0     510.0
# 9  23:00         0.6         0.3     Benjamin Bonzi     102.0     126.0
#
#    Fav_Odds  fav_percent  Fav_Serve%  Fav_Return%  fav_last_five_win_perc  \
# 5      1.85     0.555556        0.52         0.37                     0.6
# 6      1.54     0.571429        0.60         0.38                     0.6
# 7      1.56     0.666667        0.62         0.35                     0.4
# 8      1.51     1.000000        0.00         0.00                     0.4
# 9      1.81     0.833333        0.83         0.20                     0.6
#
#                    Dog  Dog_Odds  dog_percent  Dog_Serve%  Dog_Return%  \
# ...
